# %%
pip install Pillow

# %%
import numpy as np
from PIL import Image, ImageOps

# %%
import cv2
import numpy as np
image = np.array ([[1,0,2,1,0],
                   [0,2,3,0,1],
                   [1,0,1,1,0],
                   [0,2,2,0,3],
                   [0,4,1,2,0]])
image = image /5.0

# %%
kernel1 = np.array([[-1,0,1],
                    [-1,0,1],
                    [-1,0,1]])

# %%
im2 = cv2.filter2D(src=image, ddepth=-1, kernel=kernel1)

# %%
im2_int = (im2 * 5).astype('int')
im2_int
# Out:
# array([[ 0,  7, -3, -6,  0],
#        [ 0,  4,  0, -5,  0],
#        [ 0,  5, -3, -2,  0],
#        [ 0,  3, -3, -1,  0],
#        [ 0,  5, -6,  0,  0]])

# %%
imgfile = 'building_dia_R.jpg'
img = Image.open(imgfile).convert('L')
img
# Out:
# <PIL.Image.Image image mode=L size=753x566>

# %%
pixel = np.array(img)
pixel.shape
# Out:
# (566, 753)

# %% [markdown]
# ทำ Pooling เหมือน workshop 3

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import MaxPool2D, AveragePooling2D

# %%
import tensorflow as tf
from keras.layers import Lambda

# %%
arr = pixel.reshape(1,pixel.shape[0],pixel.shape[1],1)

# %%
model = Sequential()

# %% [markdown]
# Max Pooling

# %%
model.add(MaxPool2D(pool_size=(2,2)))
output = model.predict(arr)
output = np.squeeze(output)
pixel = np.array(output)
pixel.shape
Image.fromarray(output)
# Out:
# 1/1 [==============================] - 0s 124ms/step
# <PIL.Image.Image image mode=L size=376x283>

# %% [markdown]
# ทดสอบ MaxPooling size 3x3

# %%
model.add(MaxPool2D(pool_size=(3,3)))
output = model.predict(arr)
output = np.squeeze(output)
pixel = np.array(output)
pixel.shape
Image.fromarray(output)
# Out:
# 1/1 [==============================] - 0s 53ms/step
# <PIL.Image.Image image mode=L size=376x283>

# %% [markdown]
# ทดสอบ Avg Pooling size 2x2

# %%
model.add(AveragePooling2D(pool_size=(2,2)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-8c1793ef4bba> in <cell line: 1>()
# ----> 1 model.add(AveragePooling2D(pool_size=(2,2)))
#
# /usr/local/lib/python3.10/dist-packages/tensorflow/python/trackable/base.py in _method_wrapper(self, *args, **kwargs)
#     202     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     203     try:
# --> 204       result = method(self, *args, **kwargs)
#     205     finally:
#     206       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
# ...
