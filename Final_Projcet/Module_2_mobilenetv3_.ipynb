# %% [markdown]
# ##Load Data

# %%
# !nvidia-smi
# Out:
# Sat Aug 31 10:28:29 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Copy datasets
# !cp /content/drive/MyDrive/Datasets/Datasets2.zip .

# %%
# !unzip '/content/Datasets2.zip' -d '/content/'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/Datasets2/Apple_Red/A3 (351).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (352).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (353).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (354).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (355).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (356).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (357).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (358).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (359).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (36).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (360).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (361).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (362).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (363).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (364).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (365).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (366).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (367).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (368).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (369).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (37).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (370).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (371).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (372).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (373).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (374).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (375).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (376).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (377).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (378).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (379).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (38).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (380).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (381).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (382).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (383).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (384).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (385).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (386).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (387).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (388).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (389).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (39).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (390).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (391).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (392).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (393).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (394).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (395).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (396).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (397).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (398).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (399).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (4).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (40).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (400).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (401).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (402).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (403).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (404).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (405).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (406).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (407).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (408).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (409).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (41).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (410).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (411).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (412).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (413).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (414).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (415).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (416).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (417).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (418).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (419).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (42).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (420).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (421).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (422).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (423).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (424).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (425).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (426).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (427).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (428).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (429).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (43).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (44).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (45).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (46).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (47).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (48).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (49).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (5).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (50).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (51).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (52).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (53).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (54).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (55).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (56).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (57).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (58).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (59).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (6).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (60).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (61).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (62).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (63).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (64).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (65).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (66).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (67).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (68).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (69).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (7).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (70).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (71).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (72).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (73).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (74).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (75).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (76).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (77).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (78).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (79).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (8).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (80).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (81).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (82).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (83).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (84).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (85).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (86).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (87).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (88).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (89).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (9).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (90).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (91).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (92).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (93).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (94).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (95).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (96).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (97).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (98).jpg
#   inflating: /content/Datasets2/Apple_Red/A3 (99).jpg
#    creating: /content/Datasets2/Cherry/
#   inflating: /content/Datasets2/Cherry/C1 (1).jpg
#   inflating: /content/Datasets2/Cherry/C1 (10).jpg
#   inflating: /content/Datasets2/Cherry/C1 (100).jpg
#   inflating: /content/Datasets2/Cherry/C1 (101).jpg
#   inflating: /content/Datasets2/Cherry/C1 (102).jpg
#   inflating: /content/Datasets2/Cherry/C1 (103).jpg
#   inflating: /content/Datasets2/Cherry/C1 (104).jpg
#   inflating: /content/Datasets2/Cherry/C1 (105).jpg
#   inflating: /content/Datasets2/Cherry/C1 (106).jpg
#   inflating: /content/Datasets2/Cherry/C1 (107).jpg
#   inflating: /content/Datasets2/Cherry/C1 (108).jpg
#   inflating: /content/Datasets2/Cherry/C1 (109).jpg
#   inflating: /content/Datasets2/Cherry/C1 (11).jpg
#   inflating: /content/Datasets2/Cherry/C1 (110).jpg
#   inflating: /content/Datasets2/Cherry/C1 (111).jpg
#   inflating: /content/Datasets2/Cherry/C1 (112).jpg
#   inflating: /content/Datasets2/Cherry/C1 (113).jpg
#   inflating: /content/Datasets2/Cherry/C1 (114).jpg
#   inflating: /content/Datasets2/Cherry/C1 (115).jpg
#   inflating: /content/Datasets2/Cherry/C1 (116).jpg
#   inflating: /content/Datasets2/Cherry/C1 (117).jpg
#   inflating: /content/Datasets2/Cherry/C1 (118).jpg
#   inflating: /content/Datasets2/Cherry/C1 (119).jpg
#   inflating: /content/Datasets2/Cherry/C1 (12).jpg
#   inflating: /content/Datasets2/Cherry/C1 (120).jpg
#   inflating: /content/Datasets2/Cherry/C1 (121).jpg
#   inflating: /content/Datasets2/Cherry/C1 (122).jpg
#   inflating: /content/Datasets2/Cherry/C1 (123).jpg
#   inflating: /content/Datasets2/Cherry/C1 (124).jpg
#   inflating: /content/Datasets2/Cherry/C1 (125).jpg
#   inflating: /content/Datasets2/Cherry/C1 (126).jpg
#   inflating: /content/Datasets2/Cherry/C1 (127).jpg
#   inflating: /content/Datasets2/Cherry/C1 (128).jpg
#   inflating: /content/Datasets2/Cherry/C1 (129).jpg
#   inflating: /content/Datasets2/Cherry/C1 (13).jpg
#   inflating: /content/Datasets2/Cherry/C1 (130).jpg
#   inflating: /content/Datasets2/Cherry/C1 (131).jpg
#   inflating: /content/Datasets2/Cherry/C1 (132).jpg
#   inflating: /content/Datasets2/Cherry/C1 (133).jpg
#   inflating: /content/Datasets2/Cherry/C1 (134).jpg
#   inflating: /content/Datasets2/Cherry/C1 (135).jpg
#   inflating: /content/Datasets2/Cherry/C1 (136).jpg
#   inflating: /content/Datasets2/Cherry/C1 (137).jpg
#   inflating: /content/Datasets2/Cherry/C1 (138).jpg
#   inflating: /content/Datasets2/Cherry/C1 (139).jpg
#   inflating: /content/Datasets2/Cherry/C1 (14).jpg
#   inflating: /content/Datasets2/Cherry/C1 (140).jpg
#   inflating: /content/Datasets2/Cherry/C1 (141).jpg
#   inflating: /content/Datasets2/Cherry/C1 (142).jpg
#   inflating: /content/Datasets2/Cherry/C1 (143).jpg
#   inflating: /content/Datasets2/Cherry/C1 (144).jpg
#   inflating: /content/Datasets2/Cherry/C1 (145).jpg
#   inflating: /content/Datasets2/Cherry/C1 (146).jpg
#   inflating: /content/Datasets2/Cherry/C1 (147).jpg
#   inflating: /content/Datasets2/Cherry/C1 (148).jpg
#   inflating: /content/Datasets2/Cherry/C1 (149).jpg
#   inflating: /content/Datasets2/Cherry/C1 (15).jpg
#   inflating: /content/Datasets2/Cherry/C1 (150).jpg
#   inflating: /content/Datasets2/Cherry/C1 (151).jpg
#   inflating: /content/Datasets2/Cherry/C1 (152).jpg
#   inflating: /content/Datasets2/Cherry/C1 (153).jpg
#   inflating: /content/Datasets2/Cherry/C1 (154).jpg
#   inflating: /content/Datasets2/Cherry/C1 (155).jpg
#   inflating: /content/Datasets2/Cherry/C1 (156).jpg
#   inflating: /content/Datasets2/Cherry/C1 (157).jpg
#   inflating: /content/Datasets2/Cherry/C1 (158).jpg
#   inflating: /content/Datasets2/Cherry/C1 (159).jpg
#   inflating: /content/Datasets2/Cherry/C1 (16).jpg
#   inflating: /content/Datasets2/Cherry/C1 (160).jpg
#   inflating: /content/Datasets2/Cherry/C1 (161).jpg
#   inflating: /content/Datasets2/Cherry/C1 (162).jpg
#   inflating: /content/Datasets2/Cherry/C1 (163).jpg
#   inflating: /content/Datasets2/Cherry/C1 (164).jpg
#   inflating: /content/Datasets2/Cherry/C1 (165).jpg
#   inflating: /content/Datasets2/Cherry/C1 (166).jpg
#   inflating: /content/Datasets2/Cherry/C1 (167).jpg
#   inflating: /content/Datasets2/Cherry/C1 (168).jpg
#   inflating: /content/Datasets2/Cherry/C1 (169).jpg
#   inflating: /content/Datasets2/Cherry/C1 (17).jpg
#   inflating: /content/Datasets2/Cherry/C1 (170).jpg
#   inflating: /content/Datasets2/Cherry/C1 (171).jpg
#   inflating: /content/Datasets2/Cherry/C1 (172).jpg
#   inflating: /content/Datasets2/Cherry/C1 (173).jpg
#   inflating: /content/Datasets2/Cherry/C1 (174).jpg
#   inflating: /content/Datasets2/Cherry/C1 (175).jpg
#   inflating: /content/Datasets2/Cherry/C1 (176).jpg
#   inflating: /content/Datasets2/Cherry/C1 (177).jpg
#   inflating: /content/Datasets2/Cherry/C1 (178).jpg
#   inflating: /content/Datasets2/Cherry/C1 (179).jpg
#   inflating: /content/Datasets2/Cherry/C1 (18).jpg
#   inflating: /content/Datasets2/Cherry/C1 (180).jpg
#   inflating: /content/Datasets2/Cherry/C1 (181).jpg
#   inflating: /content/Datasets2/Cherry/C1 (182).jpg
#   inflating: /content/Datasets2/Cherry/C1 (183).jpg
#   inflating: /content/Datasets2/Cherry/C1 (184).jpg
#   inflating: /content/Datasets2/Cherry/C1 (185).jpg
#   inflating: /content/Datasets2/Cherry/C1 (186).jpg
#   inflating: /content/Datasets2/Cherry/C1 (187).jpg
#   inflating: /content/Datasets2/Cherry/C1 (188).jpg
#   inflating: /content/Datasets2/Cherry/C1 (189).jpg
#   inflating: /content/Datasets2/Cherry/C1 (19).jpg
#   inflating: /content/Datasets2/Cherry/C1 (190).jpg
#   inflating: /content/Datasets2/Cherry/C1 (191).jpg
#   inflating: /content/Datasets2/Cherry/C1 (192).jpg
#   inflating: /content/Datasets2/Cherry/C1 (193).jpg
#   inflating: /content/Datasets2/Cherry/C1 (194).jpg
#   inflating: /content/Datasets2/Cherry/C1 (195).jpg
#   inflating: /content/Datasets2/Cherry/C1 (196).jpg
#   inflating: /content/Datasets2/Cherry/C1 (197).jpg
#   inflating: /content/Datasets2/Cherry/C1 (198).jpg
#   inflating: /content/Datasets2/Cherry/C1 (199).jpg
#   inflating: /content/Datasets2/Cherry/C1 (2).jpg
#   inflating: /content/Datasets2/Cherry/C1 (20).jpg
#   inflating: /content/Datasets2/Cherry/C1 (200).jpg
#   inflating: /content/Datasets2/Cherry/C1 (201).jpg
#   inflating: /content/Datasets2/Cherry/C1 (202).jpg
#   inflating: /content/Datasets2/Cherry/C1 (203).jpg
#   inflating: /content/Datasets2/Cherry/C1 (204).jpg
#   inflating: /content/Datasets2/Cherry/C1 (205).jpg
#   inflating: /content/Datasets2/Cherry/C1 (206).jpg
#   inflating: /content/Datasets2/Cherry/C1 (207).jpg
#   inflating: /content/Datasets2/Cherry/C1 (208).jpg
#   inflating: /content/Datasets2/Cherry/C1 (209).jpg
#   inflating: /content/Datasets2/Cherry/C1 (21).jpg
#   inflating: /content/Datasets2/Cherry/C1 (210).jpg
#   inflating: /content/Datasets2/Cherry/C1 (211).jpg
#   inflating: /content/Datasets2/Cherry/C1 (212).jpg
#   inflating: /content/Datasets2/Cherry/C1 (213).jpg
#   inflating: /content/Datasets2/Cherry/C1 (214).jpg
#   inflating: /content/Datasets2/Cherry/C1 (215).jpg
#   inflating: /content/Datasets2/Cherry/C1 (216).jpg
#   inflating: /content/Datasets2/Cherry/C1 (217).jpg
#   inflating: /content/Datasets2/Cherry/C1 (218).jpg
#   inflating: /content/Datasets2/Cherry/C1 (219).jpg
#   inflating: /content/Datasets2/Cherry/C1 (22).jpg
#   inflating: /content/Datasets2/Cherry/C1 (220).jpg
#   inflating: /content/Datasets2/Cherry/C1 (221).jpg
#   inflating: /content/Datasets2/Cherry/C1 (222).jpg
#   inflating: /content/Datasets2/Cherry/C1 (223).jpg
#   inflating: /content/Datasets2/Cherry/C1 (224).jpg
#   inflating: /content/Datasets2/Cherry/C1 (225).jpg
#   inflating: /content/Datasets2/Cherry/C1 (226).jpg
#   inflating: /content/Datasets2/Cherry/C1 (227).jpg
#   inflating: /content/Datasets2/Cherry/C1 (228).jpg
#   inflating: /content/Datasets2/Cherry/C1 (229).jpg
#   inflating: /content/Datasets2/Cherry/C1 (23).jpg
#   inflating: /content/Datasets2/Cherry/C1 (230).jpg
#   inflating: /content/Datasets2/Cherry/C1 (231).jpg
#   inflating: /content/Datasets2/Cherry/C1 (232).jpg
#   inflating: /content/Datasets2/Cherry/C1 (233).jpg
#   inflating: /content/Datasets2/Cherry/C1 (234).jpg
#   inflating: /content/Datasets2/Cherry/C1 (235).jpg
#   inflating: /content/Datasets2/Cherry/C1 (236).jpg
#   inflating: /content/Datasets2/Cherry/C1 (237).jpg
#   inflating: /content/Datasets2/Cherry/C1 (238).jpg
#   inflating: /content/Datasets2/Cherry/C1 (239).jpg
#   inflating: /content/Datasets2/Cherry/C1 (24).jpg
#   inflating: /content/Datasets2/Cherry/C1 (240).jpg
#   inflating: /content/Datasets2/Cherry/C1 (241).jpg
#   inflating: /content/Datasets2/Cherry/C1 (242).jpg
#   inflating: /content/Datasets2/Cherry/C1 (243).jpg
#   inflating: /content/Datasets2/Cherry/C1 (244).jpg
#   inflating: /content/Datasets2/Cherry/C1 (245).jpg
#   inflating: /content/Datasets2/Cherry/C1 (246).jpg
#   inflating: /content/Datasets2/Cherry/C1 (247).jpg
#   inflating: /content/Datasets2/Cherry/C1 (248).jpg
#   inflating: /content/Datasets2/Cherry/C1 (249).jpg
#   inflating: /content/Datasets2/Cherry/C1 (25).jpg
#   inflating: /content/Datasets2/Cherry/C1 (250).jpg
#   inflating: /content/Datasets2/Cherry/C1 (251).jpg
#   inflating: /content/Datasets2/Cherry/C1 (252).jpg
#   inflating: /content/Datasets2/Cherry/C1 (253).jpg
#   inflating: /content/Datasets2/Cherry/C1 (254).jpg
#   inflating: /content/Datasets2/Cherry/C1 (255).jpg
#   inflating: /content/Datasets2/Cherry/C1 (256).jpg
#   inflating: /content/Datasets2/Cherry/C1 (257).jpg
#   inflating: /content/Datasets2/Cherry/C1 (258).jpg
#   inflating: /content/Datasets2/Cherry/C1 (259).jpg
#   inflating: /content/Datasets2/Cherry/C1 (26).jpg
#   inflating: /content/Datasets2/Cherry/C1 (260).jpg
#   inflating: /content/Datasets2/Cherry/C1 (261).jpg
#   inflating: /content/Datasets2/Cherry/C1 (262).jpg
#   inflating: /content/Datasets2/Cherry/C1 (263).jpg
#   inflating: /content/Datasets2/Cherry/C1 (264).jpg
#   inflating: /content/Datasets2/Cherry/C1 (265).jpg
#   inflating: /content/Datasets2/Cherry/C1 (266).jpg
#   inflating: /content/Datasets2/Cherry/C1 (267).jpg
#   inflating: /content/Datasets2/Cherry/C1 (268).jpg
#   inflating: /content/Datasets2/Cherry/C1 (269).jpg
#   inflating: /content/Datasets2/Cherry/C1 (27).jpg
#   inflating: /content/Datasets2/Cherry/C1 (270).jpg
#   inflating: /content/Datasets2/Cherry/C1 (271).jpg
#   inflating: /content/Datasets2/Cherry/C1 (272).jpg
#   inflating: /content/Datasets2/Cherry/C1 (273).jpg
#   inflating: /content/Datasets2/Cherry/C1 (274).jpg
#   inflating: /content/Datasets2/Cherry/C1 (275).jpg
#   inflating: /content/Datasets2/Cherry/C1 (276).jpg
#   inflating: /content/Datasets2/Cherry/C1 (277).jpg
#   inflating: /content/Datasets2/Cherry/C1 (278).jpg
#   inflating: /content/Datasets2/Cherry/C1 (279).jpg
#   inflating: /content/Datasets2/Cherry/C1 (28).jpg
#   inflating: /content/Datasets2/Cherry/C1 (280).jpg
#   inflating: /content/Datasets2/Cherry/C1 (281).jpg
#   inflating: /content/Datasets2/Cherry/C1 (282).jpg
#   inflating: /content/Datasets2/Cherry/C1 (283).jpg
#   inflating: /content/Datasets2/Cherry/C1 (284).jpg
#   inflating: /content/Datasets2/Cherry/C1 (285).jpg
#   inflating: /content/Datasets2/Cherry/C1 (286).jpg
#   inflating: /content/Datasets2/Cherry/C1 (287).jpg
#   inflating: /content/Datasets2/Cherry/C1 (288).jpg
#   inflating: /content/Datasets2/Cherry/C1 (289).jpg
#   inflating: /content/Datasets2/Cherry/C1 (29).jpg
#   inflating: /content/Datasets2/Cherry/C1 (290).jpg
#   inflating: /content/Datasets2/Cherry/C1 (291).jpg
#   inflating: /content/Datasets2/Cherry/C1 (292).jpg
#   inflating: /content/Datasets2/Cherry/C1 (293).jpg
#   inflating: /content/Datasets2/Cherry/C1 (294).jpg
#   inflating: /content/Datasets2/Cherry/C1 (295).jpg
#   inflating: /content/Datasets2/Cherry/C1 (296).jpg
#   inflating: /content/Datasets2/Cherry/C1 (297).jpg
#   inflating: /content/Datasets2/Cherry/C1 (298).jpg
#   inflating: /content/Datasets2/Cherry/C1 (299).jpg
#   inflating: /content/Datasets2/Cherry/C1 (3).jpg
#   inflating: /content/Datasets2/Cherry/C1 (30).jpg
#   inflating: /content/Datasets2/Cherry/C1 (300).jpg
#   inflating: /content/Datasets2/Cherry/C1 (301).jpg
#   inflating: /content/Datasets2/Cherry/C1 (302).jpg
#   inflating: /content/Datasets2/Cherry/C1 (303).jpg
#   inflating: /content/Datasets2/Cherry/C1 (304).jpg
#   inflating: /content/Datasets2/Cherry/C1 (305).jpg
#   inflating: /content/Datasets2/Cherry/C1 (306).jpg
#   inflating: /content/Datasets2/Cherry/C1 (307).jpg
#   inflating: /content/Datasets2/Cherry/C1 (308).jpg
#   inflating: /content/Datasets2/Cherry/C1 (309).jpg
#   inflating: /content/Datasets2/Cherry/C1 (31).jpg
#   inflating: /content/Datasets2/Cherry/C1 (310).jpg
#   inflating: /content/Datasets2/Cherry/C1 (311).jpg
#   inflating: /content/Datasets2/Cherry/C1 (312).jpg
#   inflating: /content/Datasets2/Cherry/C1 (313).jpg
#   inflating: /content/Datasets2/Cherry/C1 (314).jpg
#   inflating: /content/Datasets2/Cherry/C1 (315).jpg
#   inflating: /content/Datasets2/Cherry/C1 (316).jpg
#   inflating: /content/Datasets2/Cherry/C1 (317).jpg
#   inflating: /content/Datasets2/Cherry/C1 (318).jpg
#   inflating: /content/Datasets2/Cherry/C1 (319).jpg
#   inflating: /content/Datasets2/Cherry/C1 (32).jpg
#   inflating: /content/Datasets2/Cherry/C1 (320).jpg
#   inflating: /content/Datasets2/Cherry/C1 (321).jpg
#   inflating: /content/Datasets2/Cherry/C1 (322).jpg
#   inflating: /content/Datasets2/Cherry/C1 (323).jpg
#   inflating: /content/Datasets2/Cherry/C1 (324).jpg
#   inflating: /content/Datasets2/Cherry/C1 (325).jpg
#   inflating: /content/Datasets2/Cherry/C1 (326).jpg
#   inflating: /content/Datasets2/Cherry/C1 (327).jpg
#   inflating: /content/Datasets2/Cherry/C1 (328).jpg
#   inflating: /content/Datasets2/Cherry/C1 (329).jpg
#   inflating: /content/Datasets2/Cherry/C1 (33).jpg
#   inflating: /content/Datasets2/Cherry/C1 (330).jpg
#   inflating: /content/Datasets2/Cherry/C1 (331).jpg
#   inflating: /content/Datasets2/Cherry/C1 (332).jpg
#   inflating: /content/Datasets2/Cherry/C1 (333).jpg
#   inflating: /content/Datasets2/Cherry/C1 (334).jpg
#   inflating: /content/Datasets2/Cherry/C1 (335).jpg
#   inflating: /content/Datasets2/Cherry/C1 (336).jpg
#   inflating: /content/Datasets2/Cherry/C1 (337).jpg
#   inflating: /content/Datasets2/Cherry/C1 (338).jpg
#   inflating: /content/Datasets2/Cherry/C1 (339).jpg
#   inflating: /content/Datasets2/Cherry/C1 (34).jpg
#   inflating: /content/Datasets2/Cherry/C1 (340).jpg
#   inflating: /content/Datasets2/Cherry/C1 (341).jpg
#   inflating: /content/Datasets2/Cherry/C1 (342).jpg
#   inflating: /content/Datasets2/Cherry/C1 (343).jpg
#   inflating: /content/Datasets2/Cherry/C1 (344).jpg
#   inflating: /content/Datasets2/Cherry/C1 (345).jpg
#   inflating: /content/Datasets2/Cherry/C1 (346).jpg
#   inflating: /content/Datasets2/Cherry/C1 (347).jpg
#   inflating: /content/Datasets2/Cherry/C1 (348).jpg
#   inflating: /content/Datasets2/Cherry/C1 (349).jpg
#   inflating: /content/Datasets2/Cherry/C1 (35).jpg
#   inflating: /content/Datasets2/Cherry/C1 (350).jpg
#   inflating: /content/Datasets2/Cherry/C1 (351).jpg
#   inflating: /content/Datasets2/Cherry/C1 (352).jpg
#   inflating: /content/Datasets2/Cherry/C1 (353).jpg
#   inflating: /content/Datasets2/Cherry/C1 (354).jpg
#   inflating: /content/Datasets2/Cherry/C1 (355).jpg
#   inflating: /content/Datasets2/Cherry/C1 (356).jpg
#   inflating: /content/Datasets2/Cherry/C1 (357).jpg
#   inflating: /content/Datasets2/Cherry/C1 (358).jpg
#   inflating: /content/Datasets2/Cherry/C1 (359).jpg
#   inflating: /content/Datasets2/Cherry/C1 (36).jpg
#   inflating: /content/Datasets2/Cherry/C1 (360).jpg
#   inflating: /content/Datasets2/Cherry/C1 (361).jpg
#   inflating: /content/Datasets2/Cherry/C1 (362).jpg
#   inflating: /content/Datasets2/Cherry/C1 (363).jpg
#   inflating: /content/Datasets2/Cherry/C1 (364).jpg
#   inflating: /content/Datasets2/Cherry/C1 (365).jpg
#   inflating: /content/Datasets2/Cherry/C1 (366).jpg
#   inflating: /content/Datasets2/Cherry/C1 (367).jpg
#   inflating: /content/Datasets2/Cherry/C1 (368).jpg
#   inflating: /content/Datasets2/Cherry/C1 (369).jpg
#   inflating: /content/Datasets2/Cherry/C1 (37).jpg
#   inflating: /content/Datasets2/Cherry/C1 (370).jpg
#   inflating: /content/Datasets2/Cherry/C1 (371).jpg
#   inflating: /content/Datasets2/Cherry/C1 (372).jpg
#   inflating: /content/Datasets2/Cherry/C1 (373).jpg
#   inflating: /content/Datasets2/Cherry/C1 (374).jpg
#   inflating: /content/Datasets2/Cherry/C1 (375).jpg
#   inflating: /content/Datasets2/Cherry/C1 (376).jpg
#   inflating: /content/Datasets2/Cherry/C1 (377).jpg
#   inflating: /content/Datasets2/Cherry/C1 (378).jpg
#   inflating: /content/Datasets2/Cherry/C1 (379).jpg
#   inflating: /content/Datasets2/Cherry/C1 (38).jpg
#   inflating: /content/Datasets2/Cherry/C1 (380).jpg
#   inflating: /content/Datasets2/Cherry/C1 (381).jpg
#   inflating: /content/Datasets2/Cherry/C1 (382).jpg
#   inflating: /content/Datasets2/Cherry/C1 (383).jpg
#   inflating: /content/Datasets2/Cherry/C1 (384).jpg
#   inflating: /content/Datasets2/Cherry/C1 (385).jpg
#   inflating: /content/Datasets2/Cherry/C1 (386).jpg
#   inflating: /content/Datasets2/Cherry/C1 (387).jpg
#   inflating: /content/Datasets2/Cherry/C1 (388).jpg
#   inflating: /content/Datasets2/Cherry/C1 (389).jpg
#   inflating: /content/Datasets2/Cherry/C1 (39).jpg
#   inflating: /content/Datasets2/Cherry/C1 (390).jpg
#   inflating: /content/Datasets2/Cherry/C1 (391).jpg
#   inflating: /content/Datasets2/Cherry/C1 (392).jpg
#   inflating: /content/Datasets2/Cherry/C1 (393).jpg
#   inflating: /content/Datasets2/Cherry/C1 (394).jpg
#   inflating: /content/Datasets2/Cherry/C1 (395).jpg
#   inflating: /content/Datasets2/Cherry/C1 (396).jpg
#   inflating: /content/Datasets2/Cherry/C1 (397).jpg
#   inflating: /content/Datasets2/Cherry/C1 (398).jpg
#   inflating: /content/Datasets2/Cherry/C1 (399).jpg
#   inflating: /content/Datasets2/Cherry/C1 (4).jpg
#   inflating: /content/Datasets2/Cherry/C1 (40).jpg
#   inflating: /content/Datasets2/Cherry/C1 (400).jpg
#   inflating: /content/Datasets2/Cherry/C1 (401).jpg
#   inflating: /content/Datasets2/Cherry/C1 (402).jpg
#   inflating: /content/Datasets2/Cherry/C1 (403).jpg
#   inflating: /content/Datasets2/Cherry/C1 (404).jpg
#   inflating: /content/Datasets2/Cherry/C1 (405).jpg
#   inflating: /content/Datasets2/Cherry/C1 (406).jpg
#   inflating: /content/Datasets2/Cherry/C1 (407).jpg
#   inflating: /content/Datasets2/Cherry/C1 (408).jpg
#   inflating: /content/Datasets2/Cherry/C1 (409).jpg
#   inflating: /content/Datasets2/Cherry/C1 (41).jpg
#   inflating: /content/Datasets2/Cherry/C1 (410).jpg
#   inflating: /content/Datasets2/Cherry/C1 (411).jpg
#   inflating: /content/Datasets2/Cherry/C1 (412).jpg
#   inflating: /content/Datasets2/Cherry/C1 (413).jpg
#   inflating: /content/Datasets2/Cherry/C1 (414).jpg
#   inflating: /content/Datasets2/Cherry/C1 (415).jpg
#   inflating: /content/Datasets2/Cherry/C1 (416).jpg
#   inflating: /content/Datasets2/Cherry/C1 (417).jpg
#   inflating: /content/Datasets2/Cherry/C1 (418).jpg
#   inflating: /content/Datasets2/Cherry/C1 (419).jpg
#   inflating: /content/Datasets2/Cherry/C1 (42).jpg
#   inflating: /content/Datasets2/Cherry/C1 (420).jpg
#   inflating: /content/Datasets2/Cherry/C1 (421).jpg
#   inflating: /content/Datasets2/Cherry/C1 (422).jpg
#   inflating: /content/Datasets2/Cherry/C1 (423).jpg
#   inflating: /content/Datasets2/Cherry/C1 (424).jpg
#   inflating: /content/Datasets2/Cherry/C1 (425).jpg
#   inflating: /content/Datasets2/Cherry/C1 (426).jpg
#   inflating: /content/Datasets2/Cherry/C1 (427).jpg
#   inflating: /content/Datasets2/Cherry/C1 (428).jpg
#   inflating: /content/Datasets2/Cherry/C1 (429).jpg
#   inflating: /content/Datasets2/Cherry/C1 (43).jpg
#   inflating: /content/Datasets2/Cherry/C1 (430).jpg
#   inflating: /content/Datasets2/Cherry/C1 (431).jpg
#   inflating: /content/Datasets2/Cherry/C1 (432).jpg
#   inflating: /content/Datasets2/Cherry/C1 (433).jpg
#   inflating: /content/Datasets2/Cherry/C1 (434).jpg
#   inflating: /content/Datasets2/Cherry/C1 (435).jpg
#   inflating: /content/Datasets2/Cherry/C1 (436).jpg
#   inflating: /content/Datasets2/Cherry/C1 (437).jpg
#   inflating: /content/Datasets2/Cherry/C1 (438).jpg
#   inflating: /content/Datasets2/Cherry/C1 (439).jpg
#   inflating: /content/Datasets2/Cherry/C1 (44).jpg
#   inflating: /content/Datasets2/Cherry/C1 (440).jpg
#   inflating: /content/Datasets2/Cherry/C1 (441).jpg
#   inflating: /content/Datasets2/Cherry/C1 (442).jpg
#   inflating: /content/Datasets2/Cherry/C1 (443).jpg
#   inflating: /content/Datasets2/Cherry/C1 (444).jpg
#   inflating: /content/Datasets2/Cherry/C1 (445).jpg
#   inflating: /content/Datasets2/Cherry/C1 (446).jpg
#   inflating: /content/Datasets2/Cherry/C1 (447).jpg
#   inflating: /content/Datasets2/Cherry/C1 (448).jpg
#   inflating: /content/Datasets2/Cherry/C1 (449).jpg
#   inflating: /content/Datasets2/Cherry/C1 (45).jpg
#   inflating: /content/Datasets2/Cherry/C1 (450).jpg
#   inflating: /content/Datasets2/Cherry/C1 (451).jpg
#   inflating: /content/Datasets2/Cherry/C1 (452).jpg
#   inflating: /content/Datasets2/Cherry/C1 (453).jpg
#   inflating: /content/Datasets2/Cherry/C1 (454).jpg
#   inflating: /content/Datasets2/Cherry/C1 (455).jpg
#   inflating: /content/Datasets2/Cherry/C1 (456).jpg
#   inflating: /content/Datasets2/Cherry/C1 (457).jpg
#   inflating: /content/Datasets2/Cherry/C1 (458).jpg
#   inflating: /content/Datasets2/Cherry/C1 (459).jpg
#   inflating: /content/Datasets2/Cherry/C1 (46).jpg
#   inflating: /content/Datasets2/Cherry/C1 (460).jpg
#   inflating: /content/Datasets2/Cherry/C1 (461).jpg
#   inflating: /content/Datasets2/Cherry/C1 (462).jpg
#   inflating: /content/Datasets2/Cherry/C1 (463).jpg
#   inflating: /content/Datasets2/Cherry/C1 (464).jpg
#   inflating: /content/Datasets2/Cherry/C1 (465).jpg
#   inflating: /content/Datasets2/Cherry/C1 (466).jpg
#   inflating: /content/Datasets2/Cherry/C1 (467).jpg
#   inflating: /content/Datasets2/Cherry/C1 (468).jpg
#   inflating: /content/Datasets2/Cherry/C1 (469).jpg
#   inflating: /content/Datasets2/Cherry/C1 (47).jpg
#   inflating: /content/Datasets2/Cherry/C1 (470).jpg
#   inflating: /content/Datasets2/Cherry/C1 (471).jpg
#   inflating: /content/Datasets2/Cherry/C1 (472).jpg
#   inflating: /content/Datasets2/Cherry/C1 (473).jpg
#   inflating: /content/Datasets2/Cherry/C1 (474).jpg
#   inflating: /content/Datasets2/Cherry/C1 (475).jpg
#   inflating: /content/Datasets2/Cherry/C1 (476).jpg
#   inflating: /content/Datasets2/Cherry/C1 (477).jpg
#   inflating: /content/Datasets2/Cherry/C1 (478).jpg
#   inflating: /content/Datasets2/Cherry/C1 (479).jpg
#   inflating: /content/Datasets2/Cherry/C1 (48).jpg
#   inflating: /content/Datasets2/Cherry/C1 (480).jpg
#   inflating: /content/Datasets2/Cherry/C1 (481).jpg
#   inflating: /content/Datasets2/Cherry/C1 (482).jpg
#   inflating: /content/Datasets2/Cherry/C1 (483).jpg
#   inflating: /content/Datasets2/Cherry/C1 (484).jpg
#   inflating: /content/Datasets2/Cherry/C1 (485).jpg
#   inflating: /content/Datasets2/Cherry/C1 (486).jpg
#   inflating: /content/Datasets2/Cherry/C1 (487).jpg
#   inflating: /content/Datasets2/Cherry/C1 (488).jpg
#   inflating: /content/Datasets2/Cherry/C1 (489).jpg
#   inflating: /content/Datasets2/Cherry/C1 (49).jpg
#   inflating: /content/Datasets2/Cherry/C1 (490).jpg
#   inflating: /content/Datasets2/Cherry/C1 (491).jpg
#   inflating: /content/Datasets2/Cherry/C1 (492).jpg
#   inflating: /content/Datasets2/Cherry/C1 (5).jpg
#   inflating: /content/Datasets2/Cherry/C1 (50).jpg
#   inflating: /content/Datasets2/Cherry/C1 (51).jpg
#   inflating: /content/Datasets2/Cherry/C1 (52).jpg
#   inflating: /content/Datasets2/Cherry/C1 (53).jpg
#   inflating: /content/Datasets2/Cherry/C1 (54).jpg
#   inflating: /content/Datasets2/Cherry/C1 (55).jpg
#   inflating: /content/Datasets2/Cherry/C1 (56).jpg
#   inflating: /content/Datasets2/Cherry/C1 (57).jpg
#   inflating: /content/Datasets2/Cherry/C1 (58).jpg
#   inflating: /content/Datasets2/Cherry/C1 (59).jpg
#   inflating: /content/Datasets2/Cherry/C1 (6).jpg
#   inflating: /content/Datasets2/Cherry/C1 (60).jpg
#   inflating: /content/Datasets2/Cherry/C1 (61).jpg
#   inflating: /content/Datasets2/Cherry/C1 (62).jpg
#   inflating: /content/Datasets2/Cherry/C1 (63).jpg
#   inflating: /content/Datasets2/Cherry/C1 (64).jpg
#   inflating: /content/Datasets2/Cherry/C1 (65).jpg
#   inflating: /content/Datasets2/Cherry/C1 (66).jpg
#   inflating: /content/Datasets2/Cherry/C1 (67).jpg
#   inflating: /content/Datasets2/Cherry/C1 (68).jpg
#   inflating: /content/Datasets2/Cherry/C1 (69).jpg
#   inflating: /content/Datasets2/Cherry/C1 (7).jpg
#   inflating: /content/Datasets2/Cherry/C1 (70).jpg
#   inflating: /content/Datasets2/Cherry/C1 (71).jpg
#   inflating: /content/Datasets2/Cherry/C1 (72).jpg
#   inflating: /content/Datasets2/Cherry/C1 (73).jpg
#   inflating: /content/Datasets2/Cherry/C1 (74).jpg
#   inflating: /content/Datasets2/Cherry/C1 (75).jpg
#   inflating: /content/Datasets2/Cherry/C1 (76).jpg
#   inflating: /content/Datasets2/Cherry/C1 (77).jpg
#   inflating: /content/Datasets2/Cherry/C1 (78).jpg
#   inflating: /content/Datasets2/Cherry/C1 (79).jpg
#   inflating: /content/Datasets2/Cherry/C1 (8).jpg
#   inflating: /content/Datasets2/Cherry/C1 (80).jpg
#   inflating: /content/Datasets2/Cherry/C1 (81).jpg
#   inflating: /content/Datasets2/Cherry/C1 (82).jpg
#   inflating: /content/Datasets2/Cherry/C1 (83).jpg
#   inflating: /content/Datasets2/Cherry/C1 (84).jpg
#   inflating: /content/Datasets2/Cherry/C1 (85).jpg
#   inflating: /content/Datasets2/Cherry/C1 (86).jpg
#   inflating: /content/Datasets2/Cherry/C1 (87).jpg
#   inflating: /content/Datasets2/Cherry/C1 (88).jpg
#   inflating: /content/Datasets2/Cherry/C1 (89).jpg
#   inflating: /content/Datasets2/Cherry/C1 (9).jpg
#   inflating: /content/Datasets2/Cherry/C1 (90).jpg
#   inflating: /content/Datasets2/Cherry/C1 (91).jpg
#   inflating: /content/Datasets2/Cherry/C1 (92).jpg
#   inflating: /content/Datasets2/Cherry/C1 (93).jpg
#   inflating: /content/Datasets2/Cherry/C1 (94).jpg
#   inflating: /content/Datasets2/Cherry/C1 (95).jpg
#   inflating: /content/Datasets2/Cherry/C1 (96).jpg
#   inflating: /content/Datasets2/Cherry/C1 (97).jpg
#   inflating: /content/Datasets2/Cherry/C1 (98).jpg
#   inflating: /content/Datasets2/Cherry/C1 (99).jpg
#   inflating: /content/Datasets2/Cherry/C2 (1).jpg
#   inflating: /content/Datasets2/Cherry/C2 (10).jpg
#   inflating: /content/Datasets2/Cherry/C2 (100).jpg
#   inflating: /content/Datasets2/Cherry/C2 (101).jpg
#   inflating: /content/Datasets2/Cherry/C2 (102).jpg
#   inflating: /content/Datasets2/Cherry/C2 (103).jpg
#   inflating: /content/Datasets2/Cherry/C2 (104).jpg
#   inflating: /content/Datasets2/Cherry/C2 (105).jpg
#   inflating: /content/Datasets2/Cherry/C2 (106).jpg
#   inflating: /content/Datasets2/Cherry/C2 (107).jpg
#   inflating: /content/Datasets2/Cherry/C2 (108).jpg
#   inflating: /content/Datasets2/Cherry/C2 (109).jpg
#   inflating: /content/Datasets2/Cherry/C2 (11).jpg
#   inflating: /content/Datasets2/Cherry/C2 (110).jpg
#   inflating: /content/Datasets2/Cherry/C2 (111).jpg
#   inflating: /content/Datasets2/Cherry/C2 (112).jpg
#   inflating: /content/Datasets2/Cherry/C2 (113).jpg
#   inflating: /content/Datasets2/Cherry/C2 (114).jpg
#   inflating: /content/Datasets2/Cherry/C2 (115).jpg
#   inflating: /content/Datasets2/Cherry/C2 (116).jpg
#   inflating: /content/Datasets2/Cherry/C2 (117).jpg
#   inflating: /content/Datasets2/Cherry/C2 (118).jpg
#   inflating: /content/Datasets2/Cherry/C2 (119).jpg
#   inflating: /content/Datasets2/Cherry/C2 (12).jpg
#   inflating: /content/Datasets2/Cherry/C2 (120).jpg
#   inflating: /content/Datasets2/Cherry/C2 (121).jpg
#   inflating: /content/Datasets2/Cherry/C2 (122).jpg
#   inflating: /content/Datasets2/Cherry/C2 (123).jpg
#   inflating: /content/Datasets2/Cherry/C2 (124).jpg
#   inflating: /content/Datasets2/Cherry/C2 (125).jpg
#   inflating: /content/Datasets2/Cherry/C2 (126).jpg
#   inflating: /content/Datasets2/Cherry/C2 (127).jpg
#   inflating: /content/Datasets2/Cherry/C2 (128).jpg
#   inflating: /content/Datasets2/Cherry/C2 (129).jpg
#   inflating: /content/Datasets2/Cherry/C2 (13).jpg
#   inflating: /content/Datasets2/Cherry/C2 (130).jpg
#   inflating: /content/Datasets2/Cherry/C2 (131).jpg
#   inflating: /content/Datasets2/Cherry/C2 (132).jpg
#   inflating: /content/Datasets2/Cherry/C2 (133).jpg
#   inflating: /content/Datasets2/Cherry/C2 (134).jpg
#   inflating: /content/Datasets2/Cherry/C2 (135).jpg
#   inflating: /content/Datasets2/Cherry/C2 (136).jpg
#   inflating: /content/Datasets2/Cherry/C2 (137).jpg
#   inflating: /content/Datasets2/Cherry/C2 (138).jpg
#   inflating: /content/Datasets2/Cherry/C2 (139).jpg
#   inflating: /content/Datasets2/Cherry/C2 (14).jpg
#   inflating: /content/Datasets2/Cherry/C2 (140).jpg
#   inflating: /content/Datasets2/Cherry/C2 (141).jpg
#   inflating: /content/Datasets2/Cherry/C2 (142).jpg
#   inflating: /content/Datasets2/Cherry/C2 (143).jpg
#   inflating: /content/Datasets2/Cherry/C2 (144).jpg
#   inflating: /content/Datasets2/Cherry/C2 (145).jpg
#   inflating: /content/Datasets2/Cherry/C2 (146).jpg
#   inflating: /content/Datasets2/Cherry/C2 (147).jpg
#   inflating: /content/Datasets2/Cherry/C2 (148).jpg
#   inflating: /content/Datasets2/Cherry/C2 (149).jpg
#   inflating: /content/Datasets2/Cherry/C2 (15).jpg
#   inflating: /content/Datasets2/Cherry/C2 (150).jpg
#   inflating: /content/Datasets2/Cherry/C2 (151).jpg
#   inflating: /content/Datasets2/Cherry/C2 (152).jpg
#   inflating: /content/Datasets2/Cherry/C2 (153).jpg
#   inflating: /content/Datasets2/Cherry/C2 (154).jpg
#   inflating: /content/Datasets2/Cherry/C2 (155).jpg
#   inflating: /content/Datasets2/Cherry/C2 (156).jpg
#   inflating: /content/Datasets2/Cherry/C2 (157).jpg
#   inflating: /content/Datasets2/Cherry/C2 (158).jpg
#   inflating: /content/Datasets2/Cherry/C2 (159).jpg
#   inflating: /content/Datasets2/Cherry/C2 (16).jpg
#   inflating: /content/Datasets2/Cherry/C2 (160).jpg
#   inflating: /content/Datasets2/Cherry/C2 (161).jpg
#   inflating: /content/Datasets2/Cherry/C2 (162).jpg
#   inflating: /content/Datasets2/Cherry/C2 (163).jpg
#   inflating: /content/Datasets2/Cherry/C2 (164).jpg
#   inflating: /content/Datasets2/Cherry/C2 (165).jpg
#   inflating: /content/Datasets2/Cherry/C2 (166).jpg
#   inflating: /content/Datasets2/Cherry/C2 (167).jpg
#   inflating: /content/Datasets2/Cherry/C2 (168).jpg
#   inflating: /content/Datasets2/Cherry/C2 (169).jpg
#   inflating: /content/Datasets2/Cherry/C2 (17).jpg
#   inflating: /content/Datasets2/Cherry/C2 (170).jpg
#   inflating: /content/Datasets2/Cherry/C2 (171).jpg
#   inflating: /content/Datasets2/Cherry/C2 (172).jpg
#   inflating: /content/Datasets2/Cherry/C2 (173).jpg
#   inflating: /content/Datasets2/Cherry/C2 (174).jpg
#   inflating: /content/Datasets2/Cherry/C2 (175).jpg
#   inflating: /content/Datasets2/Cherry/C2 (176).jpg
#   inflating: /content/Datasets2/Cherry/C2 (177).jpg
#   inflating: /content/Datasets2/Cherry/C2 (178).jpg
#   inflating: /content/Datasets2/Cherry/C2 (179).jpg
#   inflating: /content/Datasets2/Cherry/C2 (18).jpg
#   inflating: /content/Datasets2/Cherry/C2 (180).jpg
#   inflating: /content/Datasets2/Cherry/C2 (181).jpg
#   inflating: /content/Datasets2/Cherry/C2 (182).jpg
#   inflating: /content/Datasets2/Cherry/C2 (183).jpg
#   inflating: /content/Datasets2/Cherry/C2 (184).jpg
#   inflating: /content/Datasets2/Cherry/C2 (185).jpg
#   inflating: /content/Datasets2/Cherry/C2 (186).jpg
#   inflating: /content/Datasets2/Cherry/C2 (187).jpg
#   inflating: /content/Datasets2/Cherry/C2 (188).jpg
#   inflating: /content/Datasets2/Cherry/C2 (189).jpg
#   inflating: /content/Datasets2/Cherry/C2 (19).jpg
#   inflating: /content/Datasets2/Cherry/C2 (190).jpg
#   inflating: /content/Datasets2/Cherry/C2 (191).jpg
#   inflating: /content/Datasets2/Cherry/C2 (192).jpg
#   inflating: /content/Datasets2/Cherry/C2 (193).jpg
#   inflating: /content/Datasets2/Cherry/C2 (194).jpg
#   inflating: /content/Datasets2/Cherry/C2 (195).jpg
#   inflating: /content/Datasets2/Cherry/C2 (196).jpg
#   inflating: /content/Datasets2/Cherry/C2 (197).jpg
#   inflating: /content/Datasets2/Cherry/C2 (198).jpg
#   inflating: /content/Datasets2/Cherry/C2 (199).jpg
#   inflating: /content/Datasets2/Cherry/C2 (2).jpg
#   inflating: /content/Datasets2/Cherry/C2 (20).jpg
#   inflating: /content/Datasets2/Cherry/C2 (200).jpg
#   inflating: /content/Datasets2/Cherry/C2 (201).jpg
#   inflating: /content/Datasets2/Cherry/C2 (202).jpg
#   inflating: /content/Datasets2/Cherry/C2 (203).jpg
#   inflating: /content/Datasets2/Cherry/C2 (204).jpg
#   inflating: /content/Datasets2/Cherry/C2 (205).jpg
#   inflating: /content/Datasets2/Cherry/C2 (206).jpg
#   inflating: /content/Datasets2/Cherry/C2 (207).jpg
#   inflating: /content/Datasets2/Cherry/C2 (208).jpg
#   inflating: /content/Datasets2/Cherry/C2 (209).jpg
#   inflating: /content/Datasets2/Cherry/C2 (21).jpg
#   inflating: /content/Datasets2/Cherry/C2 (210).jpg
#   inflating: /content/Datasets2/Cherry/C2 (211).jpg
#   inflating: /content/Datasets2/Cherry/C2 (212).jpg
#   inflating: /content/Datasets2/Cherry/C2 (213).jpg
#   inflating: /content/Datasets2/Cherry/C2 (214).jpg
#   inflating: /content/Datasets2/Cherry/C2 (215).jpg
#   inflating: /content/Datasets2/Cherry/C2 (216).jpg
#   inflating: /content/Datasets2/Cherry/C2 (217).jpg
#   inflating: /content/Datasets2/Cherry/C2 (218).jpg
#   inflating: /content/Datasets2/Cherry/C2 (219).jpg
#   inflating: /content/Datasets2/Cherry/C2 (22).jpg
#   inflating: /content/Datasets2/Cherry/C2 (220).jpg
#   inflating: /content/Datasets2/Cherry/C2 (221).jpg
#   inflating: /content/Datasets2/Cherry/C2 (222).jpg
#   inflating: /content/Datasets2/Cherry/C2 (223).jpg
#   inflating: /content/Datasets2/Cherry/C2 (224).jpg
#   inflating: /content/Datasets2/Cherry/C2 (225).jpg
#   inflating: /content/Datasets2/Cherry/C2 (226).jpg
#   inflating: /content/Datasets2/Cherry/C2 (227).jpg
#   inflating: /content/Datasets2/Cherry/C2 (228).jpg
#   inflating: /content/Datasets2/Cherry/C2 (229).jpg
#   inflating: /content/Datasets2/Cherry/C2 (23).jpg
#   inflating: /content/Datasets2/Cherry/C2 (230).jpg
#   inflating: /content/Datasets2/Cherry/C2 (231).jpg
#   inflating: /content/Datasets2/Cherry/C2 (232).jpg
#   inflating: /content/Datasets2/Cherry/C2 (233).jpg
#   inflating: /content/Datasets2/Cherry/C2 (234).jpg
#   inflating: /content/Datasets2/Cherry/C2 (235).jpg
#   inflating: /content/Datasets2/Cherry/C2 (236).jpg
#   inflating: /content/Datasets2/Cherry/C2 (237).jpg
#   inflating: /content/Datasets2/Cherry/C2 (238).jpg
#   inflating: /content/Datasets2/Cherry/C2 (239).jpg
#   inflating: /content/Datasets2/Cherry/C2 (24).jpg
#   inflating: /content/Datasets2/Cherry/C2 (240).jpg
#   inflating: /content/Datasets2/Cherry/C2 (241).jpg
#   inflating: /content/Datasets2/Cherry/C2 (242).jpg
#   inflating: /content/Datasets2/Cherry/C2 (243).jpg
#   inflating: /content/Datasets2/Cherry/C2 (244).jpg
#   inflating: /content/Datasets2/Cherry/C2 (245).jpg
#   inflating: /content/Datasets2/Cherry/C2 (246).jpg
#   inflating: /content/Datasets2/Cherry/C2 (247).jpg
#   inflating: /content/Datasets2/Cherry/C2 (248).jpg
#   inflating: /content/Datasets2/Cherry/C2 (249).jpg
#   inflating: /content/Datasets2/Cherry/C2 (25).jpg
#   inflating: /content/Datasets2/Cherry/C2 (250).jpg
#   inflating: /content/Datasets2/Cherry/C2 (251).jpg
#   inflating: /content/Datasets2/Cherry/C2 (252).jpg
#   inflating: /content/Datasets2/Cherry/C2 (253).jpg
#   inflating: /content/Datasets2/Cherry/C2 (254).jpg
#   inflating: /content/Datasets2/Cherry/C2 (255).jpg
#   inflating: /content/Datasets2/Cherry/C2 (256).jpg
#   inflating: /content/Datasets2/Cherry/C2 (257).jpg
#   inflating: /content/Datasets2/Cherry/C2 (258).jpg
#   inflating: /content/Datasets2/Cherry/C2 (259).jpg
#   inflating: /content/Datasets2/Cherry/C2 (26).jpg
#   inflating: /content/Datasets2/Cherry/C2 (260).jpg
#   inflating: /content/Datasets2/Cherry/C2 (261).jpg
#   inflating: /content/Datasets2/Cherry/C2 (262).jpg
#   inflating: /content/Datasets2/Cherry/C2 (263).jpg
#   inflating: /content/Datasets2/Cherry/C2 (264).jpg
#   inflating: /content/Datasets2/Cherry/C2 (265).jpg
#   inflating: /content/Datasets2/Cherry/C2 (266).jpg
#   inflating: /content/Datasets2/Cherry/C2 (267).jpg
#   inflating: /content/Datasets2/Cherry/C2 (268).jpg
#   inflating: /content/Datasets2/Cherry/C2 (269).jpg
#   inflating: /content/Datasets2/Cherry/C2 (27).jpg
#   inflating: /content/Datasets2/Cherry/C2 (270).jpg
#   inflating: /content/Datasets2/Cherry/C2 (271).jpg
#   inflating: /content/Datasets2/Cherry/C2 (272).jpg
#   inflating: /content/Datasets2/Cherry/C2 (273).jpg
#   inflating: /content/Datasets2/Cherry/C2 (274).jpg
#   inflating: /content/Datasets2/Cherry/C2 (275).jpg
#   inflating: /content/Datasets2/Cherry/C2 (276).jpg
#   inflating: /content/Datasets2/Cherry/C2 (277).jpg
#   inflating: /content/Datasets2/Cherry/C2 (278).jpg
#   inflating: /content/Datasets2/Cherry/C2 (279).jpg
#   inflating: /content/Datasets2/Cherry/C2 (28).jpg
#   inflating: /content/Datasets2/Cherry/C2 (280).jpg
#   inflating: /content/Datasets2/Cherry/C2 (281).jpg
#   inflating: /content/Datasets2/Cherry/C2 (282).jpg
#   inflating: /content/Datasets2/Cherry/C2 (283).jpg
#   inflating: /content/Datasets2/Cherry/C2 (284).jpg
#   inflating: /content/Datasets2/Cherry/C2 (285).jpg
#   inflating: /content/Datasets2/Cherry/C2 (286).jpg
#   inflating: /content/Datasets2/Cherry/C2 (287).jpg
#   inflating: /content/Datasets2/Cherry/C2 (288).jpg
#   inflating: /content/Datasets2/Cherry/C2 (289).jpg
#   inflating: /content/Datasets2/Cherry/C2 (29).jpg
#   inflating: /content/Datasets2/Cherry/C2 (290).jpg
#   inflating: /content/Datasets2/Cherry/C2 (291).jpg
#   inflating: /content/Datasets2/Cherry/C2 (292).jpg
#   inflating: /content/Datasets2/Cherry/C2 (293).jpg
#   inflating: /content/Datasets2/Cherry/C2 (294).jpg
#   inflating: /content/Datasets2/Cherry/C2 (295).jpg
#   inflating: /content/Datasets2/Cherry/C2 (296).jpg
#   inflating: /content/Datasets2/Cherry/C2 (297).jpg
#   inflating: /content/Datasets2/Cherry/C2 (298).jpg
#   inflating: /content/Datasets2/Cherry/C2 (299).jpg
#   inflating: /content/Datasets2/Cherry/C2 (3).jpg
#   inflating: /content/Datasets2/Cherry/C2 (30).jpg
#   inflating: /content/Datasets2/Cherry/C2 (300).jpg
#   inflating: /content/Datasets2/Cherry/C2 (301).jpg
#   inflating: /content/Datasets2/Cherry/C2 (302).jpg
#   inflating: /content/Datasets2/Cherry/C2 (303).jpg
#   inflating: /content/Datasets2/Cherry/C2 (304).jpg
#   inflating: /content/Datasets2/Cherry/C2 (305).jpg
#   inflating: /content/Datasets2/Cherry/C2 (306).jpg
#   inflating: /content/Datasets2/Cherry/C2 (307).jpg
#   inflating: /content/Datasets2/Cherry/C2 (308).jpg
#   inflating: /content/Datasets2/Cherry/C2 (309).jpg
#   inflating: /content/Datasets2/Cherry/C2 (31).jpg
#   inflating: /content/Datasets2/Cherry/C2 (310).jpg
#   inflating: /content/Datasets2/Cherry/C2 (311).jpg
#   inflating: /content/Datasets2/Cherry/C2 (312).jpg
#   inflating: /content/Datasets2/Cherry/C2 (313).jpg
#   inflating: /content/Datasets2/Cherry/C2 (314).jpg
#   inflating: /content/Datasets2/Cherry/C2 (315).jpg
# ...
#   inflating: /content/Datasets2/Pear/P2 (640).jpg
#   inflating: /content/Datasets2/Pear/P2 (641).jpg
#   inflating: /content/Datasets2/Pear/P2 (642).jpg
#   inflating: /content/Datasets2/Pear/P2 (643).jpg
#   inflating: /content/Datasets2/Pear/P2 (644).jpg
#   inflating: /content/Datasets2/Pear/P2 (645).jpg
#   inflating: /content/Datasets2/Pear/P2 (646).jpg
#   inflating: /content/Datasets2/Pear/P2 (647).jpg
#   inflating: /content/Datasets2/Pear/P2 (648).jpg
#   inflating: /content/Datasets2/Pear/P2 (649).jpg
#   inflating: /content/Datasets2/Pear/P2 (65).jpg
#   inflating: /content/Datasets2/Pear/P2 (650).jpg
#   inflating: /content/Datasets2/Pear/P2 (651).jpg
#   inflating: /content/Datasets2/Pear/P2 (652).jpg
#   inflating: /content/Datasets2/Pear/P2 (653).jpg
#   inflating: /content/Datasets2/Pear/P2 (654).jpg
#   inflating: /content/Datasets2/Pear/P2 (655).jpg
#   inflating: /content/Datasets2/Pear/P2 (656).jpg
#   inflating: /content/Datasets2/Pear/P2 (657).jpg
#   inflating: /content/Datasets2/Pear/P2 (658).jpg
#   inflating: /content/Datasets2/Pear/P2 (659).jpg
#   inflating: /content/Datasets2/Pear/P2 (66).jpg
#   inflating: /content/Datasets2/Pear/P2 (660).jpg
#   inflating: /content/Datasets2/Pear/P2 (661).jpg
#   inflating: /content/Datasets2/Pear/P2 (662).jpg
#   inflating: /content/Datasets2/Pear/P2 (663).jpg
#   inflating: /content/Datasets2/Pear/P2 (664).jpg
#   inflating: /content/Datasets2/Pear/P2 (665).jpg
#   inflating: /content/Datasets2/Pear/P2 (666).jpg
#   inflating: /content/Datasets2/Pear/P2 (667).jpg
#   inflating: /content/Datasets2/Pear/P2 (668).jpg
#   inflating: /content/Datasets2/Pear/P2 (669).jpg
#   inflating: /content/Datasets2/Pear/P2 (67).jpg
#   inflating: /content/Datasets2/Pear/P2 (670).jpg
#   inflating: /content/Datasets2/Pear/P2 (671).jpg
#   inflating: /content/Datasets2/Pear/P2 (672).jpg
#   inflating: /content/Datasets2/Pear/P2 (673).jpg
#   inflating: /content/Datasets2/Pear/P2 (674).jpg
#   inflating: /content/Datasets2/Pear/P2 (675).jpg
#   inflating: /content/Datasets2/Pear/P2 (676).jpg
#   inflating: /content/Datasets2/Pear/P2 (677).jpg
#   inflating: /content/Datasets2/Pear/P2 (678).jpg
#   inflating: /content/Datasets2/Pear/P2 (679).jpg
#   inflating: /content/Datasets2/Pear/P2 (68).jpg
#   inflating: /content/Datasets2/Pear/P2 (680).jpg
#   inflating: /content/Datasets2/Pear/P2 (681).jpg
#   inflating: /content/Datasets2/Pear/P2 (682).jpg
#   inflating: /content/Datasets2/Pear/P2 (683).jpg
#   inflating: /content/Datasets2/Pear/P2 (684).jpg
#   inflating: /content/Datasets2/Pear/P2 (685).jpg
#   inflating: /content/Datasets2/Pear/P2 (686).jpg
#   inflating: /content/Datasets2/Pear/P2 (687).jpg
#   inflating: /content/Datasets2/Pear/P2 (688).jpg
#   inflating: /content/Datasets2/Pear/P2 (689).jpg
#   inflating: /content/Datasets2/Pear/P2 (69).jpg
#   inflating: /content/Datasets2/Pear/P2 (690).jpg
#   inflating: /content/Datasets2/Pear/P2 (691).jpg
#   inflating: /content/Datasets2/Pear/P2 (692).jpg
#   inflating: /content/Datasets2/Pear/P2 (693).jpg
#   inflating: /content/Datasets2/Pear/P2 (694).jpg
#   inflating: /content/Datasets2/Pear/P2 (695).jpg
#   inflating: /content/Datasets2/Pear/P2 (696).jpg
#   inflating: /content/Datasets2/Pear/P2 (7).jpg
#   inflating: /content/Datasets2/Pear/P2 (70).jpg
#   inflating: /content/Datasets2/Pear/P2 (71).jpg
#   inflating: /content/Datasets2/Pear/P2 (72).jpg
#   inflating: /content/Datasets2/Pear/P2 (73).jpg
#   inflating: /content/Datasets2/Pear/P2 (74).jpg
#   inflating: /content/Datasets2/Pear/P2 (75).jpg
#   inflating: /content/Datasets2/Pear/P2 (76).jpg
#   inflating: /content/Datasets2/Pear/P2 (77).jpg
#   inflating: /content/Datasets2/Pear/P2 (78).jpg
#   inflating: /content/Datasets2/Pear/P2 (79).jpg
#   inflating: /content/Datasets2/Pear/P2 (8).jpg
#   inflating: /content/Datasets2/Pear/P2 (80).jpg
#   inflating: /content/Datasets2/Pear/P2 (81).jpg
#   inflating: /content/Datasets2/Pear/P2 (82).jpg
#   inflating: /content/Datasets2/Pear/P2 (83).jpg
#   inflating: /content/Datasets2/Pear/P2 (84).jpg
#   inflating: /content/Datasets2/Pear/P2 (85).jpg
#   inflating: /content/Datasets2/Pear/P2 (86).jpg
#   inflating: /content/Datasets2/Pear/P2 (87).jpg
#   inflating: /content/Datasets2/Pear/P2 (88).jpg
#   inflating: /content/Datasets2/Pear/P2 (89).jpg
#   inflating: /content/Datasets2/Pear/P2 (9).jpg
#   inflating: /content/Datasets2/Pear/P2 (90).jpg
#   inflating: /content/Datasets2/Pear/P2 (91).jpg
#   inflating: /content/Datasets2/Pear/P2 (92).jpg
#   inflating: /content/Datasets2/Pear/P2 (93).jpg
#   inflating: /content/Datasets2/Pear/P2 (94).jpg
#   inflating: /content/Datasets2/Pear/P2 (95).jpg
#   inflating: /content/Datasets2/Pear/P2 (96).jpg
#   inflating: /content/Datasets2/Pear/P2 (97).jpg
#   inflating: /content/Datasets2/Pear/P2 (98).jpg
#   inflating: /content/Datasets2/Pear/P2 (99).jpg
#   inflating: /content/Datasets2/Pear/P3 (1).jpg
#   inflating: /content/Datasets2/Pear/P3 (10).jpg
#   inflating: /content/Datasets2/Pear/P3 (100).jpg
#   inflating: /content/Datasets2/Pear/P3 (101).jpg
#   inflating: /content/Datasets2/Pear/P3 (102).jpg
#   inflating: /content/Datasets2/Pear/P3 (103).jpg
#   inflating: /content/Datasets2/Pear/P3 (104).jpg
#   inflating: /content/Datasets2/Pear/P3 (105).jpg
#   inflating: /content/Datasets2/Pear/P3 (106).jpg
#   inflating: /content/Datasets2/Pear/P3 (107).jpg
#   inflating: /content/Datasets2/Pear/P3 (108).jpg
#   inflating: /content/Datasets2/Pear/P3 (109).jpg
#   inflating: /content/Datasets2/Pear/P3 (11).jpg
#   inflating: /content/Datasets2/Pear/P3 (110).jpg
#   inflating: /content/Datasets2/Pear/P3 (111).jpg
#   inflating: /content/Datasets2/Pear/P3 (112).jpg
#   inflating: /content/Datasets2/Pear/P3 (113).jpg
#   inflating: /content/Datasets2/Pear/P3 (114).jpg
#   inflating: /content/Datasets2/Pear/P3 (115).jpg
#   inflating: /content/Datasets2/Pear/P3 (116).jpg
#   inflating: /content/Datasets2/Pear/P3 (117).jpg
#   inflating: /content/Datasets2/Pear/P3 (118).jpg
#   inflating: /content/Datasets2/Pear/P3 (119).jpg
#   inflating: /content/Datasets2/Pear/P3 (12).jpg
#   inflating: /content/Datasets2/Pear/P3 (120).jpg
#   inflating: /content/Datasets2/Pear/P3 (121).jpg
#   inflating: /content/Datasets2/Pear/P3 (122).jpg
#   inflating: /content/Datasets2/Pear/P3 (123).jpg
#   inflating: /content/Datasets2/Pear/P3 (124).jpg
#   inflating: /content/Datasets2/Pear/P3 (125).jpg
#   inflating: /content/Datasets2/Pear/P3 (126).jpg
#   inflating: /content/Datasets2/Pear/P3 (127).jpg
#   inflating: /content/Datasets2/Pear/P3 (128).jpg
#   inflating: /content/Datasets2/Pear/P3 (129).jpg
#   inflating: /content/Datasets2/Pear/P3 (13).jpg
#   inflating: /content/Datasets2/Pear/P3 (130).jpg
#   inflating: /content/Datasets2/Pear/P3 (131).jpg
#   inflating: /content/Datasets2/Pear/P3 (132).jpg
#   inflating: /content/Datasets2/Pear/P3 (133).jpg
#   inflating: /content/Datasets2/Pear/P3 (134).jpg
#   inflating: /content/Datasets2/Pear/P3 (135).jpg
#   inflating: /content/Datasets2/Pear/P3 (136).jpg
#   inflating: /content/Datasets2/Pear/P3 (137).jpg
#   inflating: /content/Datasets2/Pear/P3 (138).jpg
#   inflating: /content/Datasets2/Pear/P3 (139).jpg
#   inflating: /content/Datasets2/Pear/P3 (14).jpg
#   inflating: /content/Datasets2/Pear/P3 (140).jpg
#   inflating: /content/Datasets2/Pear/P3 (141).jpg
#   inflating: /content/Datasets2/Pear/P3 (142).jpg
#   inflating: /content/Datasets2/Pear/P3 (143).jpg
#   inflating: /content/Datasets2/Pear/P3 (144).jpg
#   inflating: /content/Datasets2/Pear/P3 (145).jpg
#   inflating: /content/Datasets2/Pear/P3 (146).jpg
#   inflating: /content/Datasets2/Pear/P3 (147).jpg
#   inflating: /content/Datasets2/Pear/P3 (148).jpg
#   inflating: /content/Datasets2/Pear/P3 (149).jpg
#   inflating: /content/Datasets2/Pear/P3 (15).jpg
#   inflating: /content/Datasets2/Pear/P3 (150).jpg
#   inflating: /content/Datasets2/Pear/P3 (151).jpg
#   inflating: /content/Datasets2/Pear/P3 (152).jpg
#   inflating: /content/Datasets2/Pear/P3 (153).jpg
#   inflating: /content/Datasets2/Pear/P3 (154).jpg
#   inflating: /content/Datasets2/Pear/P3 (155).jpg
#   inflating: /content/Datasets2/Pear/P3 (156).jpg
#   inflating: /content/Datasets2/Pear/P3 (157).jpg
#   inflating: /content/Datasets2/Pear/P3 (158).jpg
#   inflating: /content/Datasets2/Pear/P3 (159).jpg
#   inflating: /content/Datasets2/Pear/P3 (16).jpg
#   inflating: /content/Datasets2/Pear/P3 (160).jpg
#   inflating: /content/Datasets2/Pear/P3 (161).jpg
#   inflating: /content/Datasets2/Pear/P3 (162).jpg
#   inflating: /content/Datasets2/Pear/P3 (163).jpg
#   inflating: /content/Datasets2/Pear/P3 (164).jpg
#   inflating: /content/Datasets2/Pear/P3 (165).jpg
#   inflating: /content/Datasets2/Pear/P3 (166).jpg
#   inflating: /content/Datasets2/Pear/P3 (167).jpg
#   inflating: /content/Datasets2/Pear/P3 (168).jpg
#   inflating: /content/Datasets2/Pear/P3 (169).jpg
#   inflating: /content/Datasets2/Pear/P3 (17).jpg
#   inflating: /content/Datasets2/Pear/P3 (170).jpg
#   inflating: /content/Datasets2/Pear/P3 (171).jpg
#   inflating: /content/Datasets2/Pear/P3 (172).jpg
#   inflating: /content/Datasets2/Pear/P3 (173).jpg
#   inflating: /content/Datasets2/Pear/P3 (174).jpg
#   inflating: /content/Datasets2/Pear/P3 (175).jpg
#   inflating: /content/Datasets2/Pear/P3 (176).jpg
#   inflating: /content/Datasets2/Pear/P3 (177).jpg
#   inflating: /content/Datasets2/Pear/P3 (178).jpg
#   inflating: /content/Datasets2/Pear/P3 (179).jpg
#   inflating: /content/Datasets2/Pear/P3 (18).jpg
#   inflating: /content/Datasets2/Pear/P3 (180).jpg
#   inflating: /content/Datasets2/Pear/P3 (181).jpg
#   inflating: /content/Datasets2/Pear/P3 (182).jpg
#   inflating: /content/Datasets2/Pear/P3 (183).jpg
#   inflating: /content/Datasets2/Pear/P3 (184).jpg
#   inflating: /content/Datasets2/Pear/P3 (185).jpg
#   inflating: /content/Datasets2/Pear/P3 (186).jpg
#   inflating: /content/Datasets2/Pear/P3 (187).jpg
#   inflating: /content/Datasets2/Pear/P3 (188).jpg
#   inflating: /content/Datasets2/Pear/P3 (189).jpg
#   inflating: /content/Datasets2/Pear/P3 (19).jpg
#   inflating: /content/Datasets2/Pear/P3 (190).jpg
#   inflating: /content/Datasets2/Pear/P3 (191).jpg
#   inflating: /content/Datasets2/Pear/P3 (192).jpg
#   inflating: /content/Datasets2/Pear/P3 (193).jpg
#   inflating: /content/Datasets2/Pear/P3 (194).jpg
#   inflating: /content/Datasets2/Pear/P3 (195).jpg
#   inflating: /content/Datasets2/Pear/P3 (196).jpg
#   inflating: /content/Datasets2/Pear/P3 (197).jpg
#   inflating: /content/Datasets2/Pear/P3 (198).jpg
#   inflating: /content/Datasets2/Pear/P3 (199).jpg
#   inflating: /content/Datasets2/Pear/P3 (2).jpg
#   inflating: /content/Datasets2/Pear/P3 (20).jpg
#   inflating: /content/Datasets2/Pear/P3 (200).jpg
#   inflating: /content/Datasets2/Pear/P3 (201).jpg
#   inflating: /content/Datasets2/Pear/P3 (202).jpg
#   inflating: /content/Datasets2/Pear/P3 (203).jpg
#   inflating: /content/Datasets2/Pear/P3 (204).jpg
#   inflating: /content/Datasets2/Pear/P3 (205).jpg
#   inflating: /content/Datasets2/Pear/P3 (206).jpg
#   inflating: /content/Datasets2/Pear/P3 (207).jpg
#   inflating: /content/Datasets2/Pear/P3 (208).jpg
#   inflating: /content/Datasets2/Pear/P3 (209).jpg
#   inflating: /content/Datasets2/Pear/P3 (21).jpg
#   inflating: /content/Datasets2/Pear/P3 (210).jpg
#   inflating: /content/Datasets2/Pear/P3 (211).jpg
#   inflating: /content/Datasets2/Pear/P3 (212).jpg
#   inflating: /content/Datasets2/Pear/P3 (213).jpg
#   inflating: /content/Datasets2/Pear/P3 (214).jpg
#   inflating: /content/Datasets2/Pear/P3 (215).jpg
#   inflating: /content/Datasets2/Pear/P3 (22).jpg
#   inflating: /content/Datasets2/Pear/P3 (23).jpg
#   inflating: /content/Datasets2/Pear/P3 (24).jpg
#   inflating: /content/Datasets2/Pear/P3 (25).jpg
#   inflating: /content/Datasets2/Pear/P3 (26).jpg
#   inflating: /content/Datasets2/Pear/P3 (27).jpg
#   inflating: /content/Datasets2/Pear/P3 (28).jpg
#   inflating: /content/Datasets2/Pear/P3 (29).jpg
#   inflating: /content/Datasets2/Pear/P3 (3).jpg
#   inflating: /content/Datasets2/Pear/P3 (30).jpg
#   inflating: /content/Datasets2/Pear/P3 (31).jpg
#   inflating: /content/Datasets2/Pear/P3 (32).jpg
#   inflating: /content/Datasets2/Pear/P3 (33).jpg
#   inflating: /content/Datasets2/Pear/P3 (34).jpg
#   inflating: /content/Datasets2/Pear/P3 (35).jpg
#   inflating: /content/Datasets2/Pear/P3 (36).jpg
#   inflating: /content/Datasets2/Pear/P3 (37).jpg
#   inflating: /content/Datasets2/Pear/P3 (38).jpg
#   inflating: /content/Datasets2/Pear/P3 (39).jpg
#   inflating: /content/Datasets2/Pear/P3 (4).jpg
#   inflating: /content/Datasets2/Pear/P3 (40).jpg
#   inflating: /content/Datasets2/Pear/P3 (41).jpg
#   inflating: /content/Datasets2/Pear/P3 (42).jpg
#   inflating: /content/Datasets2/Pear/P3 (43).jpg
#   inflating: /content/Datasets2/Pear/P3 (44).jpg
#   inflating: /content/Datasets2/Pear/P3 (45).jpg
#   inflating: /content/Datasets2/Pear/P3 (46).jpg
#   inflating: /content/Datasets2/Pear/P3 (47).jpg
#   inflating: /content/Datasets2/Pear/P3 (48).jpg
#   inflating: /content/Datasets2/Pear/P3 (49).jpg
#   inflating: /content/Datasets2/Pear/P3 (5).jpg
#   inflating: /content/Datasets2/Pear/P3 (50).jpg
#   inflating: /content/Datasets2/Pear/P3 (51).jpg
#   inflating: /content/Datasets2/Pear/P3 (52).jpg
#   inflating: /content/Datasets2/Pear/P3 (53).jpg
#   inflating: /content/Datasets2/Pear/P3 (54).jpg
#   inflating: /content/Datasets2/Pear/P3 (55).jpg
#   inflating: /content/Datasets2/Pear/P3 (56).jpg
#   inflating: /content/Datasets2/Pear/P3 (57).jpg
#   inflating: /content/Datasets2/Pear/P3 (58).jpg
#   inflating: /content/Datasets2/Pear/P3 (59).jpg
#   inflating: /content/Datasets2/Pear/P3 (6).jpg
#   inflating: /content/Datasets2/Pear/P3 (60).jpg
#   inflating: /content/Datasets2/Pear/P3 (61).jpg
#   inflating: /content/Datasets2/Pear/P3 (62).jpg
#   inflating: /content/Datasets2/Pear/P3 (63).jpg
#   inflating: /content/Datasets2/Pear/P3 (64).jpg
#   inflating: /content/Datasets2/Pear/P3 (65).jpg
#   inflating: /content/Datasets2/Pear/P3 (66).jpg
#   inflating: /content/Datasets2/Pear/P3 (67).jpg
#   inflating: /content/Datasets2/Pear/P3 (68).jpg
#   inflating: /content/Datasets2/Pear/P3 (69).jpg
#   inflating: /content/Datasets2/Pear/P3 (7).jpg
#   inflating: /content/Datasets2/Pear/P3 (70).jpg
#   inflating: /content/Datasets2/Pear/P3 (71).jpg
#   inflating: /content/Datasets2/Pear/P3 (72).jpg
#   inflating: /content/Datasets2/Pear/P3 (73).jpg
#   inflating: /content/Datasets2/Pear/P3 (74).jpg
#   inflating: /content/Datasets2/Pear/P3 (75).jpg
#   inflating: /content/Datasets2/Pear/P3 (76).jpg
#   inflating: /content/Datasets2/Pear/P3 (77).jpg
#   inflating: /content/Datasets2/Pear/P3 (78).jpg
#   inflating: /content/Datasets2/Pear/P3 (79).jpg
#   inflating: /content/Datasets2/Pear/P3 (8).jpg
#   inflating: /content/Datasets2/Pear/P3 (80).jpg
#   inflating: /content/Datasets2/Pear/P3 (81).jpg
#   inflating: /content/Datasets2/Pear/P3 (82).jpg
#   inflating: /content/Datasets2/Pear/P3 (83).jpg
#   inflating: /content/Datasets2/Pear/P3 (84).jpg
#   inflating: /content/Datasets2/Pear/P3 (85).jpg
#   inflating: /content/Datasets2/Pear/P3 (86).jpg
#   inflating: /content/Datasets2/Pear/P3 (87).jpg
#   inflating: /content/Datasets2/Pear/P3 (88).jpg
#   inflating: /content/Datasets2/Pear/P3 (89).jpg
#   inflating: /content/Datasets2/Pear/P3 (9).jpg
#   inflating: /content/Datasets2/Pear/P3 (90).jpg
#   inflating: /content/Datasets2/Pear/P3 (91).jpg
#   inflating: /content/Datasets2/Pear/P3 (92).jpg
#   inflating: /content/Datasets2/Pear/P3 (93).jpg
#   inflating: /content/Datasets2/Pear/P3 (94).jpg
#   inflating: /content/Datasets2/Pear/P3 (95).jpg
#   inflating: /content/Datasets2/Pear/P3 (96).jpg
#   inflating: /content/Datasets2/Pear/P3 (97).jpg
#   inflating: /content/Datasets2/Pear/P3 (98).jpg
#   inflating: /content/Datasets2/Pear/P3 (99).jpg

# %%
import os
os.rename('/content/Datasets2','/content/Datasets')

# %%
#Count data
import os

# Define the paths to the directories
Apple_Red_dir = "/content/Datasets/Apple_Red"
Cherry_dir = "/content/Datasets/Cherry"
Grape_Blue_dir = "/content/Datasets/Grape_Blue"
Peach_dir = "/content/Datasets/Peach"
Pear_dir = "/content/Datasets/Pear"

# Use the os module to count the number of files in each directory
Apple_Red_count = len(os.listdir(Apple_Red_dir))
Cherry_count = len(os.listdir(Cherry_dir))
Grape_Blue_count = len(os.listdir(Grape_Blue_dir))
Peach_count = len(os.listdir(Peach_dir))
Pear_count = len(os.listdir(Pear_dir))

# Print the results
print(f"Number of files in {Apple_Red_dir}: {Apple_Red_count}")
print(f"Number of files in {Cherry_dir}: {Cherry_count}")
print(f"Number of files in {Grape_Blue_dir}: {Grape_Blue_count}")
print(f"Number of files in {Peach_dir}: {Peach_count}")
print(f"Number of files in {Pear_dir}: {Pear_count}")
# Out:
# Number of files in /content/Datasets/Apple_Red: 1413
# Number of files in /content/Datasets/Cherry: 1230
# Number of files in /content/Datasets/Grape_Blue: 984
# Number of files in /content/Datasets/Peach: 1230
# Number of files in /content/Datasets/Pear: 1403

# %%
num_Apple_Red = round(Apple_Red_count*.15)
num_Cherry = round(Cherry_count*.15)
num_Grape_Blue = round(Grape_Blue_count*.15)
num_Peach = round(Peach_count*.15)
num_Pear = round(Pear_count*.15)

print(f"Validate for fiber : {num_Apple_Red}")
print(f"Validate for fiber : {num_Cherry}")
print(f"Validate for fiber : {num_Grape_Blue}")
print(f"Validate for fiber : {num_Peach}")
print(f"Validate for fiber : {num_Pear}")
# Out:
# Validate for fiber : 212
# Validate for fiber : 184
# Validate for fiber : 148
# Validate for fiber : 184
# Validate for fiber : 210

# %%
import os
import random

# Define the paths to the source and test directories
source_dir = "/content/Datasets"
test_dir = "/content/test"

val_ratio = 0.2

# Define the number of files to select for each test category
num_Apple_Red = round(Apple_Red_count*val_ratio)
num_Cherry = round(Cherry_count*val_ratio)
num_Grape_Blue = round(Grape_Blue_count*val_ratio)
num_Peach = round(Peach_count*val_ratio)
num_Pear = round(Pear_count*val_ratio)

# Define the paths to the source directories for each test category
Apple_Red_dir = os.path.join(source_dir, "Apple_Red")
Cherry_dir = os.path.join(source_dir, "Cherry")
Grape_Blue_dir = os.path.join(source_dir, "Grape_Blue")
Peach_dir = os.path.join(source_dir, "Peach")
Pear_dir = os.path.join(source_dir, "Pear")

# Define the paths to the test directories for each test category
Apple_Red_test_dir = os.path.join(test_dir, "Apple_Red")
Cherry_test_dir = os.path.join(test_dir, "Cherry")
Grape_Blue_test_dir = os.path.join(test_dir, "Grape_Blue")
Peach_test_dir = os.path.join(test_dir, "Peach")
Pear_test_dir = os.path.join(test_dir, "Pear")

# Create the test directories if they don't already exist
os.makedirs(Apple_Red_test_dir, exist_ok=True)
os.makedirs(Cherry_test_dir, exist_ok=True)
os.makedirs(Grape_Blue_test_dir, exist_ok=True)
os.makedirs(Peach_test_dir, exist_ok=True)
os.makedirs(Pear_test_dir, exist_ok=True)

# Set the random seed for reproducibility
random.seed(42)

# Randomly select files from each source directory and move them to the corresponding test directory
Apple_Red_files = random.sample(os.listdir(Apple_Red_dir), num_Apple_Red)
for f in Apple_Red_files:
    src_file = os.path.join(Apple_Red_dir, f)
    dst_file = os.path.join(Apple_Red_test_dir, f)
    os.rename(src_file, dst_file)

Cherry_files = random.sample(os.listdir(Cherry_dir), num_Cherry)
for f in Cherry_files:
    src_file = os.path.join(Cherry_dir, f)
    dst_file = os.path.join(Cherry_test_dir, f)
    os.rename(src_file, dst_file)

Grape_Blue_files = random.sample(os.listdir(Grape_Blue_dir), num_Grape_Blue)
for f in Grape_Blue_files:
    src_file = os.path.join(Grape_Blue_dir, f)
    dst_file = os.path.join(Grape_Blue_test_dir, f)
    os.rename(src_file, dst_file)

Peach_files = random.sample(os.listdir(Peach_dir), num_Peach)
for f in Peach_files:
    src_file = os.path.join(Peach_dir, f)
    dst_file = os.path.join(Peach_test_dir, f)
    os.rename(src_file, dst_file)

Pear_files = random.sample(os.listdir(Pear_dir), num_Pear)
for f in Pear_files:
    src_file = os.path.join(Pear_dir, f)
    dst_file = os.path.join(Pear_test_dir, f)
    os.rename(src_file, dst_file)

# %%
#Count data
import os

# Define the paths to the directories
Apple_Red_dir = "/content/Datasets/Apple_Red"
Cherry_dir = "/content/Datasets/Cherry"
Grape_Blue_dir = "/content/Datasets/Grape_Blue"
Peach_dir = "/content/Datasets/Peach"
Pear_dir = "/content/Datasets/Pear"

# Use the os module to count the number of files in each directory
Apple_Red_count = len(os.listdir(Apple_Red_dir))
Cherry_count = len(os.listdir(Cherry_dir))
Grape_Blue_count = len(os.listdir(Grape_Blue_dir))
Peach_count = len(os.listdir(Peach_dir))
Pear_count = len(os.listdir(Pear_dir))

# Print the results
print(f"Number of files in {Apple_Red_dir}: {Apple_Red_count}")
print(f"Number of files in {Cherry_dir}: {Cherry_count}")
print(f"Number of files in {Grape_Blue_dir}: {Grape_Blue_count}")
print(f"Number of files in {Peach_dir}: {Peach_count}")
print(f"Number of files in {Pear_dir}: {Pear_count}")
# Out:
# Number of files in /content/Datasets/Apple_Red: 1130
# Number of files in /content/Datasets/Cherry: 984
# Number of files in /content/Datasets/Grape_Blue: 787
# Number of files in /content/Datasets/Peach: 984
# Number of files in /content/Datasets/Pear: 1122

# %%
#Count data
import os

# Define the paths to the directories
Apple_Red_dir = "/content/Datasets/Apple_Red"
Cherry_dir = "/content/Datasets/Cherry"
Grape_Blue_dir = "/content/Datasets/Grape_Blue"
Peach_dir = "/content/Datasets/Peach"
Pear_dir = "/content/Datasets/Pear"

# Use the os module to count the number of files in each directory
Apple_Red_count = len(os.listdir(Apple_Red_dir))
Cherry_count = len(os.listdir(Cherry_dir))
Grape_Blue_count = len(os.listdir(Grape_Blue_dir))
Peach_count = len(os.listdir(Peach_dir))
Pear_count = len(os.listdir(Pear_dir))

# Print the results
print(f"Number of files in {Apple_Red_dir}: {Apple_Red_count}")
print(f"Number of files in {Cherry_dir}: {Cherry_count}")
print(f"Number of files in {Grape_Blue_dir}: {Grape_Blue_count}")
print(f"Number of files in {Peach_dir}: {Peach_count}")
print(f"Number of files in {Pear_dir}: {Pear_count}")
# Out:
# Number of files in /content/Datasets/Apple_Red: 1130
# Number of files in /content/Datasets/Cherry: 984
# Number of files in /content/Datasets/Grape_Blue: 787
# Number of files in /content/Datasets/Peach: 984
# Number of files in /content/Datasets/Pear: 1122

# %% [markdown]
# #Install Timm

# %%
# Install Timm (Need to restart the runtime after finish install )
# !pip install git+https://github.com/rwightman/pytorch-image-models.git
# !pip install lightning transformers datasets evaluate pillow==9.2.0
# Out:
# Collecting git+https://github.com/rwightman/pytorch-image-models.git
#   Cloning https://github.com/rwightman/pytorch-image-models.git to /tmp/pip-req-build-m5lf8541
#   Running command git clone --filter=blob:none --quiet https://github.com/rwightman/pytorch-image-models.git /tmp/pip-req-build-m5lf8541
#   Resolved https://github.com/rwightman/pytorch-image-models.git to commit b3f3a005a0eaf9326e1dab19dbbc4a947863da4e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from timm==1.0.9) (2.4.0+cu121)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm==1.0.9) (0.19.0+cu121)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm==1.0.9) (6.0.2)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.10/dist-packages (from timm==1.0.9) (0.23.5)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm==1.0.9) (0.4.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm==1.0.9) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm==1.0.9) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm==1.0.9) (24.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm==1.0.9) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm==1.0.9) (4.66.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub->timm==1.0.9) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->timm==1.0.9) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->timm==1.0.9) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->timm==1.0.9) (3.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision->timm==1.0.9) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->timm==1.0.9) (9.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->timm==1.0.9) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm==1.0.9) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm==1.0.9) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm==1.0.9) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub->timm==1.0.9) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->timm==1.0.9) (1.3.0)
# Requirement already satisfied: lightning in /usr/local/lib/python3.10/dist-packages (2.4.0)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.42.4)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (2.21.0)
# Requirement already satisfied: evaluate in /usr/local/lib/python3.10/dist-packages (0.4.2)
# Requirement already satisfied: pillow==9.2.0 in /usr/local/lib/python3.10/dist-packages (9.2.0)
# Requirement already satisfied: PyYAML<8.0,>=5.4 in /usr/local/lib/python3.10/dist-packages (from lightning) (6.0.2)
# Requirement already satisfied: fsspec<2026.0,>=2022.5.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<2026.0,>=2022.5.0->lightning) (2024.6.1)
# Requirement already satisfied: lightning-utilities<2.0,>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from lightning) (0.11.6)
# Requirement already satisfied: packaging<25.0,>=20.0 in /usr/local/lib/python3.10/dist-packages (from lightning) (24.1)
# Requirement already satisfied: torch<4.0,>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from lightning) (2.4.0+cu121)
# Requirement already satisfied: torchmetrics<3.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from lightning) (1.4.1)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from lightning) (4.66.5)
# Requirement already satisfied: typing-extensions<6.0,>=4.4.0 in /usr/local/lib/python3.10/dist-packages (from lightning) (4.12.2)
# Requirement already satisfied: pytorch-lightning in /usr/local/lib/python3.10/dist-packages (from lightning) (2.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.5)
# Requirement already satisfied: numpy<2.0,>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.32.3)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.1.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.10.5)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from lightning-utilities<2.0,>=0.10.0->lightning) (71.0.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.7.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch<4.0,>=2.1.0->lightning) (1.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch<4.0,>=2.1.0->lightning) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch<4.0,>=2.1.0->lightning) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch<4.0,>=2.1.0->lightning) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch<4.0,>=2.1.0->lightning) (1.3.0)

# %%
import torch
import torch.nn as nn
import torchvision.transforms as T
from torch.utils.data import DataLoader, random_split, Dataset

# Pytorch Image model (TIMM) library: a library for state-of-the-art image classification
import timm
import timm.optim
import timm.scheduler
from timm.data import ImageDataset, create_dataset, create_loader
from timm.data.transforms_factory import create_transform

import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import classification_report
from PIL import Image

import evaluate

import numpy as np
import pandas as pd
from scipy import stats

from tqdm.notebook import tqdm

import glob

from sklearn.model_selection import StratifiedKFold,KFold

from lightning.fabric import Fabric

from copy import copy

import shutil

from sklearn.utils.class_weight import compute_class_weight

# %% [markdown]
# ##visualization Model

# %%
try:
    from torchinfo import summary
except:
    print("[INFO] Couldn't find torchinfo... installing it.")
    # !pip install -q torchinfo
    from torchinfo import summary
# Out:
# [INFO] Couldn't find torchinfo... installing it.

# %%
# Select model (List of available is shown above)
mobilenetv3_large_100 = "hf_hub:timm/mobilenetv3_large_100.miil_in21k_ft_in1k"
mobilenetv3_large_100_model= timm.create_model(mobilenetv3_large_100, pretrained=True, num_classes=5)
# Print a summary using torchinfo (uncomment for actual output)
summary(model=mobilenetv3_large_100_model,
        input_size=(16, 3, 224, 224), # make sure this is "input_size", not "input_shape"
        # col_names=["input_size"], # uncomment for smaller output
        col_names=["input_size", "output_size", "num_params", "trainable"],
        col_width=20,
        row_settings=["var_names"]
)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/688 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/22.1M [00:00<?, ?B/s]
# ==================================================================================================================================
# Layer (type (var_name))                            Input Shape          Output Shape         Param #              Trainable
# ==================================================================================================================================
# MobileNetV3 (MobileNetV3)                          [16, 3, 224, 224]    [16, 5]              --                   True
# ├─Conv2d (conv_stem)                               [16, 3, 224, 224]    [16, 16, 112, 112]   432                  True
# ├─BatchNormAct2d (bn1)                             [16, 16, 112, 112]   [16, 16, 112, 112]   32                   True
# │    └─Identity (drop)                             [16, 16, 112, 112]   [16, 16, 112, 112]   --                   --
# │    └─Hardswish (act)                             [16, 16, 112, 112]   [16, 16, 112, 112]   --                   --
# ├─Sequential (blocks)                              [16, 16, 112, 112]   [16, 960, 7, 7]      --                   True
# │    └─Sequential (0)                              [16, 16, 112, 112]   [16, 16, 112, 112]   --                   True
# │    │    └─DepthwiseSeparableConv (0)             [16, 16, 112, 112]   [16, 16, 112, 112]   464                  True
# │    └─Sequential (1)                              [16, 16, 112, 112]   [16, 24, 56, 56]     --                   True
# │    │    └─InvertedResidual (0)                   [16, 16, 112, 112]   [16, 24, 56, 56]     3,440                True
# │    │    └─InvertedResidual (1)                   [16, 24, 56, 56]     [16, 24, 56, 56]     4,440                True
# │    └─Sequential (2)                              [16, 24, 56, 56]     [16, 40, 28, 28]     --                   True
# │    │    └─InvertedResidual (0)                   [16, 24, 56, 56]     [16, 40, 28, 28]     10,328               True
# │    │    └─InvertedResidual (1)                   [16, 40, 28, 28]     [16, 40, 28, 28]     20,992               True
# │    │    └─InvertedResidual (2)                   [16, 40, 28, 28]     [16, 40, 28, 28]     20,992               True
# │    └─Sequential (3)                              [16, 40, 28, 28]     [16, 80, 14, 14]     --                   True
# │    │    └─InvertedResidual (0)                   [16, 40, 28, 28]     [16, 80, 14, 14]     32,080               True
# │    │    └─InvertedResidual (1)                   [16, 80, 14, 14]     [16, 80, 14, 14]     34,760               True
# │    │    └─InvertedResidual (2)                   [16, 80, 14, 14]     [16, 80, 14, 14]     31,992               True
# │    │    └─InvertedResidual (3)                   [16, 80, 14, 14]     [16, 80, 14, 14]     31,992               True
# │    └─Sequential (4)                              [16, 80, 14, 14]     [16, 112, 14, 14]    --                   True
# │    │    └─InvertedResidual (0)                   [16, 80, 14, 14]     [16, 112, 14, 14]    214,424              True
# │    │    └─InvertedResidual (1)                   [16, 112, 14, 14]    [16, 112, 14, 14]    386,120              True
# │    └─Sequential (5)                              [16, 112, 14, 14]    [16, 160, 7, 7]      --                   True
# │    │    └─InvertedResidual (0)                   [16, 112, 14, 14]    [16, 160, 7, 7]      429,224              True
# │    │    └─InvertedResidual (1)                   [16, 160, 7, 7]      [16, 160, 7, 7]      797,360              True
# │    │    └─InvertedResidual (2)                   [16, 160, 7, 7]      [16, 160, 7, 7]      797,360              True
# │    └─Sequential (6)                              [16, 160, 7, 7]      [16, 960, 7, 7]      --                   True
# │    │    └─ConvBnAct (0)                          [16, 160, 7, 7]      [16, 960, 7, 7]      155,520              True
# ├─SelectAdaptivePool2d (global_pool)               [16, 960, 7, 7]      [16, 960, 1, 1]      --                   --
# │    └─AdaptiveAvgPool2d (pool)                    [16, 960, 7, 7]      [16, 960, 1, 1]      --                   --
# │    └─Identity (flatten)                          [16, 960, 1, 1]      [16, 960, 1, 1]      --                   --
# ├─Conv2d (conv_head)                               [16, 960, 1, 1]      [16, 1280, 1, 1]     1,230,080            True
# ├─Identity (norm_head)                             [16, 1280, 1, 1]     [16, 1280, 1, 1]     --                   --
# ├─Hardswish (act2)                                 [16, 1280, 1, 1]     [16, 1280, 1, 1]     --                   --
# ├─Flatten (flatten)                                [16, 1280, 1, 1]     [16, 1280]           --                   --
# ├─Linear (classifier)                              [16, 1280]           [16, 5]              6,405                True
# ==================================================================================================================================
# Total params: 4,208,437
# Trainable params: 4,208,437
# Non-trainable params: 0
# Total mult-adds (G): 3.45
# ==================================================================================================================================
# Input size (MB): 9.63
# Forward/backward pass size (MB): 563.99
# Params size (MB): 16.74
# Estimated Total Size (MB): 590.36
# ==================================================================================================================================

# %%
# Transform image data based on ImageNet's mean and std
transforms = {
    "train": T.Compose([
        T.Resize((224, 224)),
        T.ToTensor(),
        T.Normalize(mean=torch.tensor([0.4850, 0.4560, 0.4060]), std=torch.tensor([0.2290, 0.2240, 0.2250]))
    ]),
    "test": T.Compose([
        T.Resize((224, 224)),
        T.ToTensor(),
        T.Normalize(mean=torch.tensor([0.4850, 0.4560, 0.4060]), std=torch.tensor([0.2290, 0.2240, 0.2250]))
    ])
}

# %%
train_dir = '/content/Datasets'

# %%
# Use ImageFolder to create dataset(s)
from torchvision import datasets
dataset = datasets.ImageFolder(root=train_dir, # target folder of images
                                  transform=transforms["train"], # transforms to perform on data (images)
                                  target_transform=None) # transforms to perform on labels (if necessary)

# %%
dataset.class_to_idx
# Out:
# {'Apple_Red': 0, 'Cherry': 1, 'Grape_Blue': 2, 'Peach': 3, 'Pear': 4}

# %%
len(dataset)
# Out:
# 5007

# %%
# Select device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
#Select Model
model_name = "hf_hub:timm/mobilenetv3_large_100.miil_in21k_ft_in1k"

# %%
num_epochs = 5
criterion = nn.CrossEntropyLoss()

# Cross Validation Configuration
k_splits = 5
metric = evaluate.load("accuracy")
# Out:
# Downloading builder script:   0%|          | 0.00/4.20k [00:00<?, ?B/s]

# %%
# Cross validation
kf = KFold(n_splits=k_splits, shuffle=True, random_state=42)

# %%
# Gradient Accumulation Settings
# Set to 1 for no accumulation
train_batch_size = 16
eval_batch_size = 8
num_accumulate = 1

# %%
torch.set_float32_matmul_precision('high')
fabric = Fabric(accelerator="cuda", precision="16-mixed")
fabric.launch()
# Out:
# INFO: Using 16-bit Automatic Mixed Precision (AMP)
# INFO:lightning.pytorch.utilities.rank_zero:Using 16-bit Automatic Mixed Precision (AMP)

# %%
import time

# %%
# %%time
all_eval_scores = []

for fold, (train_idx, val_idx) in enumerate(kf.split(dataset)):
    print(f"Fold {fold+1} of {k_splits}")

    # Load Model
    model = timm.create_model(model_name, pretrained=True, num_classes=5)


    # Load Optimizer and Scheduler
    optimizer = timm.optim.create_optimizer_v2(model, opt="AdamW", lr=5e-4)
    # optimizer = timm.optim.Lookahead(optimizer, alpha=0.5, k=6)    # update the slow weight every k steps
                                                                   # update the optimizer by combine slow weight and fast weight * alpha

    model, optimizer = fabric.setup(model, optimizer)

    scheduler = timm.scheduler.create_scheduler_v2(optimizer, num_epochs=num_epochs)[0]

    # Load Data: split train and valition set based on kfold
    train_dataset = torch.utils.data.Subset(dataset, train_idx)
    val_dataset = torch.utils.data.Subset(dataset, val_idx)

    train_dataloader = DataLoader(train_dataset, batch_size=train_batch_size, shuffle=True, num_workers=4, pin_memory=True)
    val_dataloader = DataLoader(val_dataset, batch_size=eval_batch_size, shuffle=False, num_workers=4, pin_memory=True)

    train_dataloader, val_dataloader = fabric.setup_dataloaders(train_dataloader, val_dataloader)

    # Reset Model Info
    info = {
        "metric_train": [],
        "metric_val": [],
        "train_loss": [],
        "val_loss": [],
        "best_metric_val": -999,
        "best_val_loss": 999,
    }

    for epoch in range(num_epochs):
        train_loss_epoch = []
        val_loss_epoch = []

        train_preds = []
        train_targets = []

        val_preds = []
        val_targets = []

        num_updates = epoch * len(train_dataloader)

        ### === Train Loop === ###
        ## Time
        s1 = time.time()

        model.train()
        for idx, batch in enumerate(tqdm(train_dataloader)):
            inputs, targets = batch
            # inputs = {k: v.to(device) for k,v in inputs.items()}
            outputs = model(inputs)
            loss = criterion(outputs, targets)

            fabric.backward(loss)

            # === Gradient Accumulation === #
            if ((idx + 1) % num_accumulate == 0) or (idx + 1 == len(train_dataloader)):
                optimizer.step()
                scheduler.step_update(num_updates=num_updates)
                optimizer.zero_grad()
            # ============================= #

            train_loss_epoch.append(loss.item())
            train_preds += outputs.argmax(-1).detach().cpu().tolist()
            train_targets += targets.tolist()
        ### ==================== ###

        # optimizer.sync_lookahead()              # Sync slow weight and fast weight
        scheduler.step(epoch + 1)

        ### === Evaluation Loop === ###
        model.eval()
        with torch.no_grad():
            for batch in tqdm(val_dataloader):
                inputs, targets = batch
                # inputs = {k: v.to(device) for k,v in inputs.items()}
                outputs = model(inputs)
                loss = criterion(outputs, targets)

                # Log Values
                val_loss_epoch.append(loss.item())
                val_preds += outputs.argmax(-1).detach().cpu().tolist()
                val_targets += targets.tolist()
        ### ======================= ###
        ## Time train finish
        s2 = time.time()
        elapsed_time = s2 - s1


        # Log Data
        metric_train = metric.compute(predictions=train_preds, references=train_targets)["accuracy"]
        metric_val = metric.compute(predictions=val_preds, references=val_targets)["accuracy"]

        info["metric_train"].append(metric_train)
        info["metric_val"].append(metric_val)

        info["train_loss"].append(np.average(train_loss_epoch))
        info["val_loss"].append(np.average(val_loss_epoch))

        if metric_val > info["best_metric_val"]:
        # if info["val_loss"][-1] < info["best_val_loss"]:
            print("New Best Score!")
            # print("New Best Val Loss")
            info["best_metric_val"] = metric_val
            # info["best_val_loss"] = info["val_loss"][-1]
            torch.save(model, f"mobilenetv3_large_100_checkpoint_fold{fold}.pt")

        print(f"Using time of Fold: {fold} | Epoch: {epoch} | {elapsed_time} second ")
        print(info)
        print(f"Fold: {fold} | Epoch: {epoch} | Metric: {metric_val} | Training Loss: {np.average(train_loss_epoch)} | Validation Loss: {np.average(val_loss_epoch)}")

    # save all best metric val
    all_eval_scores.append(info["best_metric_val"])
# Out:
# Fold 1 of 5
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   0%|          | 0/251 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#   0%|          | 0/126 [00:00<?, ?it/s]
# New Best Score!
# Using time of Fold: 0 | Epoch: 0 | 29.697630405426025 second
# {'metric_train': [0.9620474406991261], 'metric_val': [0.999001996007984], 'train_loss': [0.31572136171081694], 'val_loss': [0.006363362600656628], 'best_metric_val': 0.999001996007984, 'best_val_loss': 999}
# Fold: 0 | Epoch: 0 | Metric: 0.999001996007984 | Training Loss: 0.31572136171081694 | Validation Loss: 0.006363362600656628
#   0%|          | 0/251 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#   0%|          | 0/126 [00:00<?, ?it/s]
# New Best Score!
# Using time of Fold: 0 | Epoch: 1 | 27.865827798843384 second
# {'metric_train': [0.9620474406991261, 0.9895131086142323], 'metric_val': [0.999001996007984, 1.0], 'train_loss': [0.31572136171081694, 0.13098312208747576], 'val_loss': [0.006363362600656628, 4.393869372681671e-07], 'best_metric_val': 1.0, 'best_val_loss': 999}
# Fold: 0 | Epoch: 1 | Metric: 1.0 | Training Loss: 0.13098312208747576 | Validation Loss: 4.393869372681671e-07
#   0%|          | 0/251 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#   0%|          | 0/126 [00:00<?, ?it/s]
# Using time of Fold: 0 | Epoch: 2 | 28.92143201828003 second
# {'metric_train': [0.9620474406991261, 0.9895131086142323, 0.997003745318352], 'metric_val': [0.999001996007984, 1.0, 1.0], 'train_loss': [0.31572136171081694, 0.13098312208747576, 0.02549583382801882], 'val_loss': [0.006363362600656628, 4.393869372681671e-07, 0.0], 'best_metric_val': 1.0, 'best_val_loss': 999}
# Fold: 0 | Epoch: 2 | Metric: 1.0 | Training Loss: 0.02549583382801882 | Validation Loss: 0.0
#   0%|          | 0/251 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#   0%|          | 0/126 [00:00<?, ?it/s]
# Using time of Fold: 0 | Epoch: 3 | 25.284765005111694 second
# {'metric_train': [0.9620474406991261, 0.9895131086142323, 0.997003745318352, 0.9997503121098626], 'metric_val': [0.999001996007984, 1.0, 1.0, 1.0], 'train_loss': [0.31572136171081694, 0.13098312208747576, 0.02549583382801882, 0.00075692758344588], 'val_loss': [0.006363362600656628, 4.393869372681671e-07, 0.0, 0.0], 'best_metric_val': 1.0, 'best_val_loss': 999}
# Fold: 0 | Epoch: 3 | Metric: 1.0 | Training Loss: 0.00075692758344588 | Validation Loss: 0.0
#   0%|          | 0/251 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#   0%|          | 0/126 [00:00<?, ?it/s]
# Using time of Fold: 0 | Epoch: 4 | 27.433804988861084 second
# {'metric_train': [0.9620474406991261, 0.9895131086142323, 0.997003745318352, 0.9997503121098626, 1.0], 'metric_val': [0.999001996007984, 1.0, 1.0, 1.0, 1.0], 'train_loss': [0.31572136171081694, 0.13098312208747576, 0.02549583382801882, 0.00075692758344588, 7.119741592074964e-05], 'val_loss': [0.006363362600656628, 4.393869372681671e-07, 0.0, 0.0, 0.0], 'best_metric_val': 1.0, 'best_val_loss': 999}
# Fold: 0 | Epoch: 4 | Metric: 1.0 | Training Loss: 7.119741592074964e-05 | Validation Loss: 0.0
# Fold 2 of 5
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   0%|          | 0/251 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#   0%|          | 0/126 [00:00<?, ?it/s]
# New Best Score!
# Using time of Fold: 1 | Epoch: 0 | 24.702468633651733 second
# {'metric_train': [0.9568039950062422], 'metric_val': [0.9970059880239521], 'train_loss': [0.3562726430922184], 'val_loss': [0.004961226676040855], 'best_metric_val': 0.9970059880239521, 'best_val_loss': 999}
# Fold: 1 | Epoch: 0 | Metric: 0.9970059880239521 | Training Loss: 0.3562726430922184 | Validation Loss: 0.004961226676040855
#   0%|          | 0/251 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#   0%|          | 0/126 [00:00<?, ?it/s]
# New Best Score!
# Using time of Fold: 1 | Epoch: 1 | 28.08228898048401 second
# {'metric_train': [0.9568039950062422, 0.9932584269662922], 'metric_val': [0.9970059880239521, 1.0], 'train_loss': [0.3562726430922184, 0.05233437487486628], 'val_loss': [0.004961226676040855, 1.741959166119094e-07], 'best_metric_val': 1.0, 'best_val_loss': 999}
# Fold: 1 | Epoch: 1 | Metric: 1.0 | Training Loss: 0.05233437487486628 | Validation Loss: 1.741959166119094e-07
#   0%|          | 0/251 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#   0%|          | 0/126 [00:00<?, ?it/s]
# Using time of Fold: 1 | Epoch: 2 | 28.976592779159546 second
# {'metric_train': [0.9568039950062422, 0.9932584269662922, 0.997003745318352], 'metric_val': [0.9970059880239521, 1.0, 0.9580838323353293], 'train_loss': [0.3562726430922184, 0.05233437487486628, 0.01493250664710396], 'val_loss': [0.004961226676040855, 1.741959166119094e-07, 0.27027970292924475], 'best_metric_val': 1.0, 'best_val_loss': 999}
# Fold: 1 | Epoch: 2 | Metric: 0.9580838323353293 | Training Loss: 0.01493250664710396 | Validation Loss: 0.27027970292924475
#   0%|          | 0/251 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#   0%|          | 0/126 [00:00<?, ?it/s]
# Using time of Fold: 1 | Epoch: 3 | 26.77153468132019 second
# {'metric_train': [0.9568039950062422, 0.9932584269662922, 0.997003745318352, 0.9982521847690387], 'metric_val': [0.9970059880239521, 1.0, 0.9580838323353293, 1.0], 'train_loss': [0.3562726430922184, 0.05233437487486628, 0.01493250664710396, 0.025510379683436224], 'val_loss': [0.004961226676040855, 1.741959166119094e-07, 0.27027970292924475, 1.7820663727754377e-07], 'best_metric_val': 1.0, 'best_val_loss': 999}
# Fold: 1 | Epoch: 3 | Metric: 1.0 | Training Loss: 0.025510379683436224 | Validation Loss: 1.7820663727754377e-07
#   0%|          | 0/251 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#   0%|          | 0/126 [00:00<?, ?it/s]
# Using time of Fold: 1 | Epoch: 4 | 25.697649717330933 second
# {'metric_train': [0.9568039950062422, 0.9932584269662922, 0.997003745318352, 0.9982521847690387, 0.998501872659176], 'metric_val': [0.9970059880239521, 1.0, 0.9580838323353293, 1.0, 1.0], 'train_loss': [0.3562726430922184, 0.05233437487486628, 0.01493250664710396, 0.025510379683436224, 0.004950296040880652], 'val_loss': [0.004961226676040855, 1.741959166119094e-07, 0.27027970292924475, 1.7820663727754377e-07, 2.3061052016846444e-08], 'best_metric_val': 1.0, 'best_val_loss': 999}
# Fold: 1 | Epoch: 4 | Metric: 1.0 | Training Loss: 0.004950296040880652 | Validation Loss: 2.3061052016846444e-08
# Fold 3 of 5
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   0%|          | 0/251 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#   0%|          | 0/126 [00:00<?, ?it/s]
# New Best Score!
# Using time of Fold: 2 | Epoch: 0 | 26.82454776763916 second
# {'metric_train': [0.9570644033949076], 'metric_val': [0.981018981018981], 'train_loss': [0.45200766067576675], 'val_loss': [0.08804973773646761], 'best_metric_val': 0.981018981018981, 'best_val_loss': 999}
# Fold: 2 | Epoch: 0 | Metric: 0.981018981018981 | Training Loss: 0.45200766067576675 | Validation Loss: 0.08804973773646761
#   0%|          | 0/251 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#   0%|          | 0/126 [00:00<?, ?it/s]
# New Best Score!
# Using time of Fold: 2 | Epoch: 1 | 25.28536343574524 second
# {'metric_train': [0.9570644033949076, 0.9847728407388917], 'metric_val': [0.981018981018981, 0.999000999000999], 'train_loss': [0.45200766067576675, 0.11809649643627751], 'val_loss': [0.08804973773646761, 0.007227103137022449], 'best_metric_val': 0.999000999000999, 'best_val_loss': 999}
# Fold: 2 | Epoch: 1 | Metric: 0.999000999000999 | Training Loss: 0.11809649643627751 | Validation Loss: 0.007227103137022449
#   0%|          | 0/251 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#   0%|          | 0/126 [00:00<?, ?it/s]
# New Best Score!
# Using time of Fold: 2 | Epoch: 2 | 28.38784885406494 second
# {'metric_train': [0.9570644033949076, 0.9847728407388917, 0.9972541188217674], 'metric_val': [0.981018981018981, 0.999000999000999, 1.0], 'train_loss': [0.45200766067576675, 0.11809649643627751, 0.010680768711258056], 'val_loss': [0.08804973773646761, 0.007227103137022449, 0.0], 'best_metric_val': 1.0, 'best_val_loss': 999}
# Fold: 2 | Epoch: 2 | Metric: 1.0 | Training Loss: 0.010680768711258056 | Validation Loss: 0.0
#   0%|          | 0/251 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#   0%|          | 0/126 [00:00<?, ?it/s]
# Using time of Fold: 2 | Epoch: 3 | 30.177318334579468 second
# {'metric_train': [0.9570644033949076, 0.9847728407388917, 0.9972541188217674, 0.9995007488766849], 'metric_val': [0.981018981018981, 0.999000999000999, 1.0, 1.0], 'train_loss': [0.45200766067576675, 0.11809649643627751, 0.010680768711258056, 0.0026687631445793765], 'val_loss': [0.08804973773646761, 0.007227103137022449, 0.0, 0.0], 'best_metric_val': 1.0, 'best_val_loss': 999}
# Fold: 2 | Epoch: 3 | Metric: 1.0 | Training Loss: 0.0026687631445793765 | Validation Loss: 0.0
#   0%|          | 0/251 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#   0%|          | 0/126 [00:00<?, ?it/s]
# Using time of Fold: 2 | Epoch: 4 | 25.137279987335205 second
# {'metric_train': [0.9570644033949076, 0.9847728407388917, 0.9972541188217674, 0.9995007488766849, 1.0], 'metric_val': [0.981018981018981, 0.999000999000999, 1.0, 1.0, 1.0], 'train_loss': [0.45200766067576675, 0.11809649643627751, 0.010680768711258056, 0.0026687631445793765, 0.00016824414723121725], 'val_loss': [0.08804973773646761, 0.007227103137022449, 0.0, 0.0, 0.0], 'best_metric_val': 1.0, 'best_val_loss': 999}
# Fold: 2 | Epoch: 4 | Metric: 1.0 | Training Loss: 0.00016824414723121725 | Validation Loss: 0.0
# Fold 4 of 5
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   0%|          | 0/251 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#   0%|          | 0/126 [00:00<?, ?it/s]
# New Best Score!
# Using time of Fold: 3 | Epoch: 0 | 28.316202878952026 second
# {'metric_train': [0.9638042935596605], 'metric_val': [1.0], 'train_loss': [0.31447771100390476], 'val_loss': [0.0002071310585888328], 'best_metric_val': 1.0, 'best_val_loss': 999}
# Fold: 3 | Epoch: 0 | Metric: 1.0 | Training Loss: 0.31447771100390476 | Validation Loss: 0.0002071310585888328
#   0%|          | 0/251 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#   0%|          | 0/126 [00:00<?, ?it/s]
# Using time of Fold: 3 | Epoch: 1 | 25.2255642414093 second
# {'metric_train': [0.9638042935596605, 0.9755366949575637], 'metric_val': [1.0, 0.998001998001998], 'train_loss': [0.31447771100390476, 0.30153544042304126], 'val_loss': [0.0002071310585888328, 0.018902989641553517], 'best_metric_val': 1.0, 'best_val_loss': 999}
# Fold: 3 | Epoch: 1 | Metric: 0.998001998001998 | Training Loss: 0.30153544042304126 | Validation Loss: 0.018902989641553517
#   0%|          | 0/251 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#   0%|          | 0/126 [00:00<?, ?it/s]
# Using time of Fold: 3 | Epoch: 2 | 28.172935485839844 second
# {'metric_train': [0.9638042935596605, 0.9755366949575637, 0.9970044932601099], 'metric_val': [1.0, 0.998001998001998, 1.0], 'train_loss': [0.31447771100390476, 0.30153544042304126, 0.02180399494181659], 'val_loss': [0.0002071310585888328, 0.018902989641553517, 0.0], 'best_metric_val': 1.0, 'best_val_loss': 999}
# Fold: 3 | Epoch: 2 | Metric: 1.0 | Training Loss: 0.02180399494181659 | Validation Loss: 0.0
#   0%|          | 0/251 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#   0%|          | 0/126 [00:00<?, ?it/s]
# Using time of Fold: 3 | Epoch: 3 | 26.353434801101685 second
# {'metric_train': [0.9638042935596605, 0.9755366949575637, 0.9970044932601099, 0.9992511233150274], 'metric_val': [1.0, 0.998001998001998, 1.0, 1.0], 'train_loss': [0.31447771100390476, 0.30153544042304126, 0.02180399494181659, 0.0024586402380083194], 'val_loss': [0.0002071310585888328, 0.018902989641553517, 0.0, 0.0], 'best_metric_val': 1.0, 'best_val_loss': 999}
# Fold: 3 | Epoch: 3 | Metric: 1.0 | Training Loss: 0.0024586402380083194 | Validation Loss: 0.0
#   0%|          | 0/251 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#   0%|          | 0/126 [00:00<?, ?it/s]
# Using time of Fold: 3 | Epoch: 4 | 30.44015908241272 second
# {'metric_train': [0.9638042935596605, 0.9755366949575637, 0.9970044932601099, 0.9992511233150274, 0.9995007488766849], 'metric_val': [1.0, 0.998001998001998, 1.0, 1.0, 1.0], 'train_loss': [0.31447771100390476, 0.30153544042304126, 0.02180399494181659, 0.0024586402380083194, 0.0004909964670968142], 'val_loss': [0.0002071310585888328, 0.018902989641553517, 0.0, 0.0, 0.0], 'best_metric_val': 1.0, 'best_val_loss': 999}
# Fold: 3 | Epoch: 4 | Metric: 1.0 | Training Loss: 0.0004909964670968142 | Validation Loss: 0.0
# Fold 5 of 5
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#   0%|          | 0/251 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#   0%|          | 0/126 [00:00<?, ?it/s]
# New Best Score!
# Using time of Fold: 4 | Epoch: 0 | 25.93692922592163 second
# {'metric_train': [0.9600599101347979], 'metric_val': [0.968031968031968], 'train_loss': [0.30594413900873046], 'val_loss': [0.4323767279265049], 'best_metric_val': 0.968031968031968, 'best_val_loss': 999}
# Fold: 4 | Epoch: 0 | Metric: 0.968031968031968 | Training Loss: 0.30594413900873046 | Validation Loss: 0.4323767279265049
#   0%|          | 0/251 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#   0%|          | 0/126 [00:00<?, ?it/s]
# New Best Score!
# Using time of Fold: 4 | Epoch: 1 | 28.03407073020935 second
# {'metric_train': [0.9600599101347979, 0.9737893160259611], 'metric_val': [0.968031968031968, 1.0], 'train_loss': [0.30594413900873046, 0.31948373508455225], 'val_loss': [0.4323767279265049, 7.75475124344931e-06], 'best_metric_val': 1.0, 'best_val_loss': 999}
# Fold: 4 | Epoch: 1 | Metric: 1.0 | Training Loss: 0.31948373508455225 | Validation Loss: 7.75475124344931e-06
#   0%|          | 0/251 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#   0%|          | 0/126 [00:00<?, ?it/s]
# Using time of Fold: 4 | Epoch: 2 | 25.555111169815063 second
# {'metric_train': [0.9600599101347979, 0.9737893160259611, 0.9970044932601099], 'metric_val': [0.968031968031968, 1.0, 1.0], 'train_loss': [0.30594413900873046, 0.31948373508455225, 0.01645296267651145], 'val_loss': [0.4323767279265049, 7.75475124344931e-06, 6.117989240274897e-05], 'best_metric_val': 1.0, 'best_val_loss': 999}
# Fold: 4 | Epoch: 2 | Metric: 1.0 | Training Loss: 0.01645296267651145 | Validation Loss: 6.117989240274897e-05
#   0%|          | 0/251 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# /usr/local/lib/python3.10/dist-packages/lightning/fabric/fabric.py in backward(self, tensor, model, *args, **kwargs)
#     442         lightning.fabric.wrappers._in_fabric_backward = True
#     443         try:
# --> 444             self._strategy.backward(tensor, module, *args, **kwargs)
#     445         finally:
#     446             lightning.fabric.wrappers._in_fabric_backward = False
#
# /usr/local/lib/python3.10/dist-packages/lightning/fabric/strategies/strategy.py in backward(self, tensor, module, *args, **kwargs)
#     186         r"""Forwards backward-calls to the precision plugin."""
#     187         self.precision.pre_backward(tensor, module)
# --> 188         self.precision.backward(tensor, module, *args, **kwargs)
#     189         self.precision.post_backward(tensor, module)
#     190
#
# /usr/local/lib/python3.10/dist-packages/lightning/fabric/plugins/precision/amp.py in backward(self, tensor, model, *args, **kwargs)
#      75         if self.scaler is not None:
#      76             tensor = self.scaler.scale(tensor)
# ---> 77         super().backward(tensor, model, *args, **kwargs)
#      78
#      79     @override
#
# /usr/local/lib/python3.10/dist-packages/lightning/fabric/plugins/precision/precision.py in backward(self, tensor, model, *args, **kwargs)
#     105
#     106         """
# --> 107         tensor.backward(*args, **kwargs)
#     108
#     109     def post_backward(self, tensor: Tensor, module: Optional[Module]) -> Any:
#
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     519                 inputs=inputs,
#     520             )
# --> 521         torch.autograd.backward(
#     522             self, gradient, retain_graph, create_graph, inputs=inputs
#     523         )
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     287     # some Python versions print out the first line of a multi-line function
#     288     # calls in the traceback and some print out the last line
# --> 289     _engine_run_backward(
#     290         tensors,
#     291         grad_tensors_,
#
# /usr/local/lib/python3.10/dist-packages/torch/autograd/graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     766         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     767     try:
# --> 768         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     769             t_outputs, *args, **kwargs
#     770         )  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %%
classname = dataset.classes
classname
# Out:
# ['Apple_Red', 'Cherry', 'Grape_Blue', 'Peach', 'Pear']

# %%
for fold in range(k_splits):
    predictions = []
    references = []

    # load model
    loaded_model = torch.load(f"mobilenetv3_large_100_checkpoint_fold{fold}.pt")
    # Evaluation
    loaded_model.eval()
    with torch.no_grad():
        for batch in tqdm(val_dataloader):
            inputs, targets = batch
            outputs = loaded_model(inputs.to(device))

            # Log Values
            predictions += outputs.argmax(-1).detach().cpu().tolist()
            references += targets.tolist()

    print(f"Fold: {fold}")

    # Confusion matrix
    cm = confusion_matrix(references, predictions)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=classname)
    disp.plot()
    plt.show()

    # Classification Report
    print(classification_report(references, predictions, target_names=classname))
# Out:
# <ipython-input-29-7ec0dabfebea>:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   loaded_model = torch.load(f"mobilenetv3_large_100_checkpoint_fold{fold}.pt")
#   0%|          | 0/126 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Fold: 0
#               precision    recall  f1-score   support
#
#    Apple_Red       1.00      1.00      1.00       213
#       Cherry       1.00      1.00      1.00       192
#   Grape_Blue       1.00      1.00      1.00       163
#        Peach       1.00      1.00      1.00       213
#         Pear       1.00      1.00      1.00       220
#
#     accuracy                           1.00      1001
#    macro avg       1.00      1.00      1.00      1001
# weighted avg       1.00      1.00      1.00      1001
# <ipython-input-29-7ec0dabfebea>:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   loaded_model = torch.load(f"mobilenetv3_large_100_checkpoint_fold{fold}.pt")
#   0%|          | 0/126 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Fold: 1
#               precision    recall  f1-score   support
#
#    Apple_Red       1.00      1.00      1.00       213
#       Cherry       1.00      1.00      1.00       192
#   Grape_Blue       1.00      1.00      1.00       163
#        Peach       1.00      1.00      1.00       213
#         Pear       1.00      1.00      1.00       220
#
#     accuracy                           1.00      1001
#    macro avg       1.00      1.00      1.00      1001
# weighted avg       1.00      1.00      1.00      1001
# <ipython-input-29-7ec0dabfebea>:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   loaded_model = torch.load(f"mobilenetv3_large_100_checkpoint_fold{fold}.pt")
#   0%|          | 0/126 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Fold: 2
#               precision    recall  f1-score   support
#
#    Apple_Red       1.00      1.00      1.00       213
#       Cherry       1.00      1.00      1.00       192
#   Grape_Blue       1.00      1.00      1.00       163
#        Peach       1.00      1.00      1.00       213
#         Pear       1.00      1.00      1.00       220
#
#     accuracy                           1.00      1001
#    macro avg       1.00      1.00      1.00      1001
# weighted avg       1.00      1.00      1.00      1001
# <ipython-input-29-7ec0dabfebea>:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   loaded_model = torch.load(f"mobilenetv3_large_100_checkpoint_fold{fold}.pt")
#   0%|          | 0/126 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Fold: 3
#               precision    recall  f1-score   support
#
#    Apple_Red       1.00      1.00      1.00       213
#       Cherry       1.00      1.00      1.00       192
#   Grape_Blue       1.00      1.00      1.00       163
#        Peach       1.00      1.00      1.00       213
#         Pear       1.00      1.00      1.00       220
#
#     accuracy                           1.00      1001
#    macro avg       1.00      1.00      1.00      1001
# weighted avg       1.00      1.00      1.00      1001
# <ipython-input-29-7ec0dabfebea>:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   loaded_model = torch.load(f"mobilenetv3_large_100_checkpoint_fold{fold}.pt")
#   0%|          | 0/126 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Fold: 4
#               precision    recall  f1-score   support
#
#    Apple_Red       1.00      1.00      1.00       213
#       Cherry       1.00      1.00      1.00       192
#   Grape_Blue       1.00      1.00      1.00       163
#        Peach       1.00      1.00      1.00       213
#         Pear       1.00      1.00      1.00       220
#
#     accuracy                           1.00      1001
#    macro avg       1.00      1.00      1.00      1001
# weighted avg       1.00      1.00      1.00      1001

# %%
classname = dataset.classes
classname
# Out:
# ['Apple_Red', 'Cherry', 'Grape_Blue', 'Peach', 'Pear']

# %% [markdown]
# ###Verification by sepreate data

# %%
test_folder = '/content/test'

# %%
# Making Dataset
from torchvision import datasets
test_dataset = datasets.ImageFolder(root=test_folder, # target folder of images
                                  transform=transforms["test"], # transforms to perform on data (images)
                                  target_transform=None) # transforms to perform on labels (if necessary)

# %%
len(test_dataset)
# Out:
# 1253

# %%
# Making test dataloader
test_dataloader = DataLoader(test_dataset, batch_size=eval_batch_size, shuffle=False, num_workers=4, pin_memory=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(

# %%
test_dataset.classes
# Out:
# ['Apple_Red', 'Cherry', 'Grape_Blue', 'Peach', 'Pear']

# %%
len(test_dataloader)
# Out:
# 157

# %%
for fold in range(k_splits):
    predictions = []
    references = []

    # load model
    loaded_model = torch.load(f"mobilenetv3_large_100_checkpoint_fold{fold}.pt")
    # Evaluation
    loaded_model.eval()
    with torch.no_grad():
        for batch in tqdm(test_dataloader):
            inputs, targets = batch
            outputs = loaded_model(inputs.to(device))

            # Log Values
            predictions += outputs.argmax(-1).detach().cpu().tolist()
            references += targets.tolist()

    print(f"Fold: {fold}")

    # Confusion matrix
    cm = confusion_matrix(references, predictions)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=classname)
    disp.plot()
    plt.show()

    # Classification Report
    print(classification_report(references, predictions, target_names=classname))
# Out:
# <ipython-input-37-26018ac0e9af>:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   loaded_model = torch.load(f"mobilenetv3_large_100_checkpoint_fold{fold}.pt")
#   0%|          | 0/157 [00:00<?, ?it/s]
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Fold: 0
#               precision    recall  f1-score   support
#
#    Apple_Red       1.00      1.00      1.00       283
#       Cherry       1.00      1.00      1.00       246
#   Grape_Blue       1.00      1.00      1.00       197
#        Peach       1.00      1.00      1.00       246
#         Pear       1.00      1.00      1.00       281
#
#     accuracy                           1.00      1253
#    macro avg       1.00      1.00      1.00      1253
# weighted avg       1.00      1.00      1.00      1253
# <ipython-input-37-26018ac0e9af>:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   loaded_model = torch.load(f"mobilenetv3_large_100_checkpoint_fold{fold}.pt")
#   0%|          | 0/157 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Fold: 1
#               precision    recall  f1-score   support
#
#    Apple_Red       1.00      1.00      1.00       283
#       Cherry       1.00      1.00      1.00       246
#   Grape_Blue       1.00      1.00      1.00       197
#        Peach       1.00      1.00      1.00       246
#         Pear       1.00      1.00      1.00       281
#
#     accuracy                           1.00      1253
#    macro avg       1.00      1.00      1.00      1253
# weighted avg       1.00      1.00      1.00      1253
# <ipython-input-37-26018ac0e9af>:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   loaded_model = torch.load(f"mobilenetv3_large_100_checkpoint_fold{fold}.pt")
#   0%|          | 0/157 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Fold: 2
#               precision    recall  f1-score   support
#
#    Apple_Red       1.00      1.00      1.00       283
#       Cherry       1.00      1.00      1.00       246
#   Grape_Blue       1.00      1.00      1.00       197
#        Peach       1.00      1.00      1.00       246
#         Pear       1.00      1.00      1.00       281
#
#     accuracy                           1.00      1253
#    macro avg       1.00      1.00      1.00      1253
# weighted avg       1.00      1.00      1.00      1253
# <ipython-input-37-26018ac0e9af>:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   loaded_model = torch.load(f"mobilenetv3_large_100_checkpoint_fold{fold}.pt")
#   0%|          | 0/157 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Fold: 3
#               precision    recall  f1-score   support
#
#    Apple_Red       1.00      1.00      1.00       283
#       Cherry       1.00      1.00      1.00       246
#   Grape_Blue       1.00      1.00      1.00       197
#        Peach       1.00      1.00      1.00       246
#         Pear       1.00      1.00      1.00       281
#
#     accuracy                           1.00      1253
#    macro avg       1.00      1.00      1.00      1253
# weighted avg       1.00      1.00      1.00      1253
# <ipython-input-37-26018ac0e9af>:6: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   loaded_model = torch.load(f"mobilenetv3_large_100_checkpoint_fold{fold}.pt")
#   0%|          | 0/157 [00:00<?, ?it/s]
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()

# %% [markdown]
# ##Visualization train model result

# %%
## Making Pridcition return class & prob
from typing import List, Tuple

from PIL import Image
def pred_class(model: torch.nn.Module,
                        image_path: str,
                        class_names: List[str],
                        image_size: Tuple[int, int] = (224, 224),
                        transform: T = None,
                        device: torch.device=device):


    # 2. Open image
    img = Image.open(image_path)

    # 3. Create transformation for image (if one doesn't exist)
    if transform is not None:
        image_transform = transform
    else:
        image_transform = transforms.Compose([
            transforms.Resize(image_size),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225]),
        ])

    ### Predict on image ###

    # 4. Make sure the model is on the target device
    model.to(device)

    # 5. Turn on model evaluation mode and inference mode
    model.eval()
    with torch.inference_mode():
      # 6. Transform and add an extra dimension to image (model requires samples in [batch_size, color_channels, height, width])
      transformed_image = image_transform(img).unsqueeze(dim=0)

      # 7. Make a prediction on image with an extra dimension and send it to the target device
      target_image_pred = model(transformed_image.to(device))

    # 8. Convert logits -> prediction probabilities (using torch.softmax() for multi-class classification)
    target_image_pred_probs = torch.softmax(target_image_pred, dim=1)

    # 9. Convert prediction probabilities -> prediction labels
    target_image_pred_label = torch.argmax(target_image_pred_probs, dim=1)

    classname =  class_names[target_image_pred_label]
    prob = target_image_pred_probs.max().cpu().numpy()

    return classname , prob

# %%
##Load some model
loaded_model = torch.load('/content/mobilenetv3_large_100_checkpoint_fold0.pt')

# %% [markdown]
# ##Train data visulization

# %%
#Making df for random
import os
import pandas as pd
from PIL import Image

# create an empty list to store image paths
image_paths = []

# loop through each subfolder in the "Image" directory
for root, dirs, files in os.walk('/content/test'):
    for subfolder_name in dirs:
        # get the path to the subfolder
        subfolder_path = os.path.join(root, subfolder_name)
        # loop through each file in the subfolder
        for filename in os.listdir(subfolder_path):
            image_path = os.path.join(subfolder_path, filename)
            image_paths.append((image_path, subfolder_name))

# create a DataFrame from the list of image paths
df = pd.DataFrame(image_paths, columns=['path', 'subfolder_name'])

# %%
df.head()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image



def sample_picture(df=df,random_state=None):
    # Sample 20 random rows from the DataFrame
    sample_df = df.sample(20, random_state=random_state).copy()
    sample_df = sample_df.reset_index(drop=True)
    # Define the grid layout for displaying the images
    num_rows = 4
    num_cols = 5
    fig, axs = plt.subplots(num_rows, num_cols, figsize=(15, 12))
    fig.tight_layout(pad=5.0)

    # Iterate over the sampled rows and display the images in the grid
    for i, row in sample_df.iterrows():
        img = Image.open(row['path'])

        # Prediction
        pred_name , prob = pred_class(model=loaded_model,image_path=row['path'],
                   class_names = classname,
                   transform=transforms["test"])

        row_idx = i // num_cols
        col_idx = i % num_cols
        axs[row_idx, col_idx].imshow(img)
        axs[row_idx, col_idx].axis('on')
        axs[row_idx, col_idx].set_title(row['subfolder_name'] + ': \nPredict:' + pred_name + '\nProb:'+ str(prob.round(decimals=2)) )

        # prediction


    plt.show()

# %%
sample_picture()

# %%
sample_picture()

# %%
sample_picture()

# %%
sample_picture()

# %%
sample_picture()

# %%
sample_picture()

# %% [markdown]
# ## Outsite data testing

# %%
# !wget https://universe.roboflow.com/ds/fx3tNSqjNJ?key=N4VBuJEAJf

# %%
# !unzip /content/fx3tNSqjNJ?key=N4VBuJEAJf

# %%
import pandas as pd
train_df = pd.read_csv('/content/train/_classes.csv')

# %%
#Count all value in train data set
train_df[(train_df == 1)].sum()

# %%
#Sum all Sphere fiber fragment sheet sum = 1 if one class sum >1 is multiclass
train_df['Sum'] = train_df[' Apple_Red'] + train_df[' Cherry'] + train_df[' Grape_Blue'] + train_df[' Peach'] + train_df[' Pear']

# %%
# Count Multiclass pictures
train_df[(train_df['Sum']> 1)].count()

# %%
# Delete multiclass picture
train_df = train_df[train_df['Sum'] == 1]

# %%
# Count remain
train_df[(train_df == 1)].sum()

# %%
# Seperate in to dataset/Sphere , dataset/fiber, dataset/fragment, dataset/sheet,
import os
import shutil

# read the file names and classes into a pandas dataframe
df =train_df

# define the source and destination directories
src_dir = '/content/train'
dst_dir = '/content/dataset'

# loop through each row in the dataframe
for idx, row in df.iterrows():
    # get the filename and class label
    filename = row['filename']

    # check if the class label is 1
    if row[' Apple_Red'] == 1:
        # create the destination directory if it doesn't exist
        dst_subdir = os.path.join(dst_dir,'Apple_Red')
        os.makedirs(dst_subdir, exist_ok=True)

        # copy the file to the destination directory
        src_path = os.path.join(src_dir, filename)
        dst_path = os.path.join(dst_subdir, filename)
        shutil.copyfile(src_path, dst_path)
    elif row[' Cherry'] == 1:
        # create the destination directory if it doesn't exist
        dst_subdir = os.path.join(dst_dir, 'Cherry')
        os.makedirs(dst_subdir, exist_ok=True)

        # copy the file to the destination directory
        src_path = os.path.join(src_dir, filename)
        dst_path = os.path.join(dst_subdir, filename)
        shutil.copyfile(src_path, dst_path)
    elif row[' Grape_Blue'] == 1:
        # create the destination directory if it doesn't exist
        dst_subdir = os.path.join(dst_dir, 'Grape_Blue')
        os.makedirs(dst_subdir, exist_ok=True)

        # copy the file to the destination directory
        src_path = os.path.join(src_dir, filename)
        dst_path = os.path.join(dst_subdir, filename)
        shutil.copyfile(src_path, dst_path)
    elif row[' Peach'] == 1:
        # create the destination directory if it doesn't exist
        dst_subdir = os.path.join(dst_dir, 'Peach')
        os.makedirs(dst_subdir, exist_ok=True)

        # copy the file to the destination directory
        src_path = os.path.join(src_dir, filename)
        dst_path = os.path.join(dst_subdir, filename)
        shutil.copyfile(src_path, dst_path)
    elif row[' Pear'] == 1:
        # create the destination directory if it doesn't exist
        dst_subdir = os.path.join(dst_dir, 'Pear')
        os.makedirs(dst_subdir, exist_ok=True)

        # copy the file to the destination directory
        src_path = os.path.join(src_dir, filename)
        dst_path = os.path.join(dst_subdir, filename)
        shutil.copyfile(src_path, dst_path)

# %%
#Making df of another for random
import os
import pandas as pd
from PIL import Image

# create an empty list to store image paths
image_paths = []

# loop through each subfolder in the "Image" directory
for root, dirs, files in os.walk('/content/dataset'):
    for subfolder_name in dirs:
        # get the path to the subfolder
        subfolder_path = os.path.join(root, subfolder_name)
        # loop through each file in the subfolder
        for filename in os.listdir(subfolder_path):
            image_path = os.path.join(subfolder_path, filename)
            image_paths.append((image_path, subfolder_name))

# create a DataFrame from the list of image paths
other_df = pd.DataFrame(image_paths, columns=['path', 'subfolder_name'])

# %%
other_df.head()

# %%
sample_picture(df=other_df)

# %%
sample_picture(df=other_df)

# %%
sample_picture(df=other_df)

# %%
sample_picture(df=other_df)

# %%
sample_picture(df=other_df)

# %%
sample_picture(df=other_df)

# %%
sample_picture(df=other_df)

# %%
sample_picture(df=other_df)

# %%
sample_picture(df=other_df)

# %%
sample_picture(df=other_df)

# %%
sample_picture(df=other_df)

# %%
sample_picture(df=other_df)

# %%
# !cp /content/mobilenetv3_large_100_checkpoint_fold0.pt /content/drive/MyDrive/Datasets/Trial15_mobienetv3
# !cp /content/mobilenetv3_large_100_checkpoint_fold1.pt /content/drive/MyDrive/Datasets/Trial15_mobienetv3
# !cp /content/mobilenetv3_large_100_checkpoint_fold2.pt /content/drive/MyDrive/Datasets/Trial15_mobienetv3
# !cp /content/mobilenetv3_large_100_checkpoint_fold3.pt /content/drive/MyDrive/Datasets/Trial15_mobienetv3
# !cp /content/mobilenetv3_large_100_checkpoint_fold4.pt /content/drive/MyDrive/Datasets/Trial15_mobienetv3

# %%
# !nvidia-smi
